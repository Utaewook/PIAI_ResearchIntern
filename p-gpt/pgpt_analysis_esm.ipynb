# %%
import pandas as pd

import re
from wordcloud import WordCloud as wc
from konlpy.tag import Okt
import nltk
from nltk import word_tokenize, pos_tag
from nltk.corpus import stopwords

from collections import Counter

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\piai\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\piai\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\piai\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
dir_path = '../data/'
paths = ['P-GPT_log_EIC기술부_김세현.xlsx','P-GPT_log_에너지조선마케팅실_유태욱.csv','P-GPT_log_재무실_유태욱.csv',
         'P-GPT_log_포항에너지부_황양하.csv','P-GPT_log_포항제강설비부_황양하.csv']

# %%
korean_stopwords = '의 가 이 은 들 는 좀 잘 걍 과 도 를 으로 자 에 와 한 하다 고 있다 때문 제 주로 위 1 2 3 4 5 6 7 8 9 0'
with open(dir_path+'stopwords.txt', 'r', encoding='utf-8') as file:
    lines = [line.strip() for line in file]


def extract_korean_nouns(text):
    okt = Okt()
    nouns = okt.nouns(text)    
    return nouns


# 불용어 삭제
def remove_korean_stopwords(text):
    stop_words = set(korean_stopwords.split())
    stop_words.update(lines)
    pattern = re.compile(r'^설명.*')
    result = [word for word in text if not pattern.match(word) and word not in stop_words]
    return result


def extract_english_nouns(text):
    tokens = word_tokenize(text)
    nouns = [word for word, pos in pos_tag(tokens) if pos.startswith('N')]
    return nouns


def remove_english_stopwords(text):
    stop_words = set(stopwords.words('english'))
    result = [word for word in text if word.lower() not in stop_words]
    return result

# %%
# df_src = pd.read_excel(dir_path+paths[0])  # EIC 기술부
df_src = pd.read_csv(dir_path+paths[1])  # 에너지 조선 마케팅
# df_src = pd.read_csv(dir_path+paths[2])  # 재무
# df_src = pd.read_csv(dir_path+paths[3])  # 에너지부
# df_src = pd.read_csv(dir_path+paths[4])  # 조선 제강 설비

# %%
df_src.head()
# Out:
#    Unnamed: 0  CreatedDatetime  UserCode Department  \
# 0         429  2023-03-07 6:39        79  에너지조선마케팅실
# 1         439  2023-03-07 6:40        79  에너지조선마케팅실
# 2         442  2023-03-07 6:41        79  에너지조선마케팅실
# 3         462  2023-03-07 6:47        79  에너지조선마케팅실
# 4         494  2023-03-07 6:54        79  에너지조선마케팅실
#
#                                         UserQuestion    Model  ResponseTime  \
# 0                                      오늘 저녁 메뉴 추천해줘  gpt-3.5             8
# 1                          포만감이 높으면서 칼로리는 낮은 한식 추천해줘  gpt-3.5            15
# 2            니가 추천해준 메뉴를 잘하는 식당을 알려줘 송파 경찰병원역 근처면 좋아  gpt-3.5            15
# 3             주소가 다 같은데 상호명만 다르게 하면 다른 식당이야? 똑바로 안해?  gpt-3.5             8
# 4  can you recommend best korean restaurant near ...  gpt-3.5             9
#
#    Unnamed: 7
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
df_temp = df_src[['UserCode','UserQuestion','Unnamed: 7']]
df_temp = df_temp.rename(columns={'Unnamed: 7':'라벨'})

# %%
df_temp.head()
# Out:
#    UserCode                                       UserQuestion  라벨
# 0        79                                      오늘 저녁 메뉴 추천해줘   1
# 1        79                          포만감이 높으면서 칼로리는 낮은 한식 추천해줘   1
# 2        79            니가 추천해준 메뉴를 잘하는 식당을 알려줘 송파 경찰병원역 근처면 좋아   1
# 3        79             주소가 다 같은데 상호명만 다르게 하면 다른 식당이야? 똑바로 안해?   1
# 4        79  can you recommend best korean restaurant near ...   1

# %%
df_temp['Nouns'] = df_temp['UserQuestion'].apply(lambda x:extract_korean_nouns(str(x))+extract_english_nouns(str(x)))
df_temp
# Out:
#       UserCode                                       UserQuestion  라벨  \
# 0           79                                      오늘 저녁 메뉴 추천해줘   1
# 1           79                          포만감이 높으면서 칼로리는 낮은 한식 추천해줘   1
# 2           79            니가 추천해준 메뉴를 잘하는 식당을 알려줘 송파 경찰병원역 근처면 좋아   1
# 3           79             주소가 다 같은데 상호명만 다르게 하면 다른 식당이야? 똑바로 안해?   1
# 4           79  can you recommend best korean restaurant near ...   1
# ...        ...                                                ...  ..
# 1869      2385           리더로써 업무 비윤리 및 인간존중 등 윤리관련 우수 사항을 작성해주세요.   2
# 1870      2642                                        아래 내용 해석해줘.   4
# 1871      2642   \r\n\r\n\r\n\r\nSl.No.\r\nDocuments\r\nRemark...   2
# 1872      2642  아래 표 내용 해석해줘.\r\n \r\n\r\n\r\n\r\nl.No.\r\nDoc...   4
# 1873        79                           "고객사의 발급 요청 지연" 영어로 번역해줘   4
#
#                                                   Nouns
# 0                        [오늘, 저녁, 메뉴, 추천, 저녁, 메뉴, 추천해줘]
# 1        [포만, 감, 칼로리, 한식, 추천, 높으면서, 칼로리는, 낮은, 한식, 추천해줘]
# 2     [니, 추천, 메뉴, 식당, 송파, 경찰병원역, 근처, 추천해준, 메뉴를, 잘하는,...
# 3     [주소, 상호, 다른, 식당, 똑바로, 안해, 다, 같은데, 상호명만, 다르게, 하...
# 4     [restaurant, National, Police, Hospital, Songp...
# ...                                                 ...
# 1869  [리더, 로써, 업무, 비, 윤리, 및, 인간, 존중, 등, 윤리, 관련, 우수, ...
# 1870                             [아래, 내용, 해석, 내용, 해석해줘]
# 1871  [Sl.No, Documents, Estimation, Corrosion, Rate...
# 1872  [아래, 표, 내용, 해석, 표, 내용, 해석해줘, l.No, Documents, ...
# 1873  [고객, 사의, 발급, 요청, 지연, 영어, 번역, 발급, 요청, 지연, 영어로, ...
#
# [1874 rows x 4 columns]

# %%
df_temp = df_temp[df_temp['라벨'].isin([2,3,5])]
df_temp
# Out:
#       UserCode                                       UserQuestion  라벨  \
# 14         203  hanseunghyuk@posco.com으로 회의참석 메일 적어죠.2023.03.0...   3
# 29         203                                      Mn 시세를 찾고 싶은데   2
# 30         203                                       망간 시세를 찾고싶은데   2
# 31         203                        런던 금속 거래소에서 망간 가격 찾는 방법 알려죠   2
# 37         203                                     스테인리스 304 제작방버   2
# ...        ...                                                ...  ..
# 1863       473  ▣ 철강협회-중부발전-에넬엑스코리아 철강산업 탄소중립 및 재생에너지 확대를 위한 전...   3
# 1867      2385                  그룹장으로써 타의 모범이 되는 사례를 간략하게 작성해주세요.   2
# 1868      2385     \r\n그룹장으로써 리더십 관점에서 타의 모범이 되는 사례를 간략하게 작성해주세요.   2
# 1869      2385           리더로써 업무 비윤리 및 인간존중 등 윤리관련 우수 사항을 작성해주세요.   2
# 1871      2642   \r\n\r\n\r\n\r\nSl.No.\r\nDocuments\r\nRemark...   2
#
#                                                   Nouns
# 14    [회의, 참석, 메일, 호, 결산, 회의, hanseunghyuk, @, posco...
# 29                               [시세, Mn, 시세를, 찾고, 싶은데]
# 30                                 [망간, 시세, 시세를, 찾고싶은데]
# 31    [런던, 금속, 거래소, 망간, 가격, 방법, 금속, 거래소에서, 망간, 가격, 찾...
# 37                                [스테인리스, 제작, 방버, 제작방버]
# ...                                                 ...
# 1863  [철강, 협회, 중부, 발전, 넬, 엑스, 코리아, 철강, 산업, 탄소, 중립, 및...
# 1867  [그룹, 타의, 모범, 사례, 작성, 타의, 모범이, 되는, 사례를, 간략하게, 작...
# 1868  [그룹, 리더십, 관점, 타의, 모범, 사례, 작성, 리더십, 관점에서, 타의, 모...
# 1869  [리더, 로써, 업무, 비, 윤리, 및, 인간, 존중, 등, 윤리, 관련, 우수, ...
# 1871  [Sl.No, Documents, Estimation, Corrosion, Rate...
#
# [998 rows x 4 columns]

# %%
df_temp['Nouns'] = df_temp['Nouns'].apply(lambda x: remove_korean_stopwords(x)+remove_english_stopwords(x))
df_temp
# Out:
# C:\Users\piai\AppData\Local\Temp\ipykernel_10656\3149459001.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['Nouns'] = df_temp['Nouns'].apply(lambda x: remove_korean_stopwords(x)+remove_english_stopwords(x))
#       UserCode                                       UserQuestion  라벨  \
# 14         203  hanseunghyuk@posco.com으로 회의참석 메일 적어죠.2023.03.0...   3
# 29         203                                      Mn 시세를 찾고 싶은데   2
# 30         203                                       망간 시세를 찾고싶은데   2
# 31         203                        런던 금속 거래소에서 망간 가격 찾는 방법 알려죠   2
# 37         203                                     스테인리스 304 제작방버   2
# ...        ...                                                ...  ..
# 1863       473  ▣ 철강협회-중부발전-에넬엑스코리아 철강산업 탄소중립 및 재생에너지 확대를 위한 전...   3
# 1867      2385                  그룹장으로써 타의 모범이 되는 사례를 간략하게 작성해주세요.   2
# 1868      2385     \r\n그룹장으로써 리더십 관점에서 타의 모범이 되는 사례를 간략하게 작성해주세요.   2
# 1869      2385           리더로써 업무 비윤리 및 인간존중 등 윤리관련 우수 사항을 작성해주세요.   2
# 1871      2642   \r\n\r\n\r\n\r\nSl.No.\r\nDocuments\r\nRemark...   2
#
#                                                   Nouns
# 14    [회의, 참석, 메일, 호, 결산, 회의, hanseunghyuk, @, posco...
# 29         [시세, Mn, 시세를, 찾고, 싶은데, 시세, Mn, 시세를, 찾고, 싶은데]
# 30             [망간, 시세, 시세를, 찾고싶은데, 망간, 시세, 시세를, 찾고싶은데]
# 31    [런던, 금속, 거래소, 망간, 가격, 방법, 금속, 거래소에서, 망간, 가격, 찾...
# 37           [스테인리스, 제작, 방버, 제작방버, 스테인리스, 제작, 방버, 제작방버]
# ...                                                 ...
# 1863  [철강, 협회, 중부, 발전, 넬, 엑스, 코리아, 철강, 산업, 탄소, 중립, 재...
# 1867  [그룹, 타의, 모범, 사례, 작성, 타의, 모범이, 되는, 사례를, 간략하게, 작...
# 1868  [그룹, 리더십, 관점, 타의, 모범, 사례, 작성, 리더십, 관점에서, 타의, 모...
# 1869  [리더, 업무, 비, 윤리, 인간, 존중, 윤리, 관련, 우수, 사항, 작성, 업무...
# 1871  [Sl.No, Documents, Estimation, Corrosion, Rate...
#
# [998 rows x 4 columns]

# %%
df_temp.groupby('라벨').count()
# Out:
#     UserCode  UserQuestion  Nouns
# 라벨
# 2        404           404    404
# 3        566           566    566
# 5         28            28     28

# %%
df_users_keyword = df_temp.groupby(['UserCode'])['Nouns'].sum()
df_users_keyword
# Out:
# UserCode
# 79      [포스코, 대해, 알, 내용, 알고, 있는, 내용, 포스코, 대해, 알, 내용, 설...
# 203     [회의, 참석, 메일, 호, 결산, 회의, hanseunghyuk, @, posco...
# 279     [공정, 담당자, 긴급, 생산, 요청, 메일, 작성, 긴급생산, 요청하는, 메일, ...
# 297     [대한민국, 풍력, 타워, 풍력, 타워, 대한민국, 풍력, 타워, 풍력, 타워, 대...
# 473     [이사회, 인사말, 인사말, 알려줘, 이사회, 인사말, 인사말, 알려줘, 친환경, ...
# 941     [price, plate, steel, price, plate, steel, 열교환...
# 965     [소개, 대본, 작성, 대본, 자기, 소개, 대본, 작성, 대본, 광양, 소, 탄소...
# 1321    [선박, 연료, 유, 종류, 연료유, 종류는, 선박, 연료, 유, 종류, 연료유, ...
# 1372    [주물, 제품, 종류, 만드는, 제품의, 종류를, 알려줘, 주물, 제품, 종류, 만...
# 1780    [=, y가, x는, =, y가, x는, =, y가, x는, =, 에서, y가, x...
# 2227    [difference, s355kl, s355kt, difference, s355k...
# 2384    [친환경, 강재, 위원회, 참석, 내빈, 대상, 위원회, 회장, 인사말, 참석하는,...
# 2385    [친환경, 에너지, 강재, 위원회, 이사회, 의장, 인사말, 격식, 작성, 이사회,...
# 2457    [포스코, 몇개, 몇개야, 포스코, 고로, 몇개, 고로, 몇개야, 몇개, POSCO...
# 2557    [선박, 엔진, 시장, 점유, 율, 대해, 시장, 점유율에, 알려주세요, 선박, 엔...
# 2624    [풍력발전, 용, 소재, 판매, 확대, 위햇, 활동, 요, 소재, 판매, 확대를, ...
# 2630    [고객, 체결, 시, 인사, 감사, 말, 안내, 부탁, MOU, 체결시, 인사, 감...
# 2642    [뜻, trough가, 뜻이야, 무슨, 뜻, trough가, 무슨, 뜻이야, 태양열...
# 2647    [산업, 안전, 보건, 법, 보호대, 고용, 노무, 제공, 사람, 산업, 재해, 보...
# 2768    [•How, economies, scale, organization, time, m...
# 3147    [회의, 록, 회의록, 만들어줘, 회의, 록, 회의록, 만들어줘, 녹음, 거, 회의...
# 3253    [report, acquisition, Daewoo, Shipbuilding, Co...
# 3264    [메일, 확인, 내용, 요약, 기능, 코딩, 확인하고, 내용을, 요약해주는, 기능을...
# Name: Nouns, dtype: object

# %%
df_temp_2 = df_temp[df_temp['라벨'] == 2]
df2 = df_temp_2.groupby(['UserCode'])['Nouns'].sum()
df2
# Out:
# UserCode
# 79      [포스코, 대해, 알, 내용, 알고, 있는, 내용, 포스코, 대해, 알, 내용, 설...
# 203     [시세, Mn, 시세를, 찾고, 싶은데, 시세, Mn, 시세를, 찾고, 싶은데, 망...
# 279     [철강, 후판, 생산, 공정은, 후판의, 생산, 공정은, 것이, 있습니까, 철강, ...
# 297     [대한민국, 풍력, 타워, 풍력, 타워, 대한민국, 풍력, 타워, 풍력, 타워, 대...
# 473     [이사회, 인사말, 인사말, 알려줘, 이사회, 인사말, 인사말, 알려줘, 재난, 관...
# 941     [price, plate, steel, price, plate, steel, 열교환...
# 965     [광양, 소, 탄소강, 후판, 날판, 평균, 실수, 율, 대로, 유지, 게, 실수,...
# 1321    [선박, 연료, 유, 종류, 연료유, 종류는, 선박, 연료, 유, 종류, 연료유, ...
# 1372    [주물, 제품, 종류, 만드는, 제품의, 종류를, 알려줘, 주물, 제품, 종류, 만...
# 1780    [=, y가, x는, =, y가, x는, =, y가, x는, =, 에서, y가, x...
# 2227    [difference, s355kl, s355kt, difference, s355k...
# 2384           [rust, zinc, coating, rust, zinc, coating]
# 2385    [module, Frame, development, contents, module,...
# 2457    [포스코, 몇개, 몇개야, 포스코, 고로, 몇개, 고로, 몇개야, 몇개, POSCO...
# 2557    [선박, 엔진, 시장, 점유, 율, 대해, 시장, 점유율에, 알려주세요, 선박, 엔...
# 2624    [풍력발전, 용, 소재, 판매, 확대, 위햇, 활동, 요, 소재, 판매, 확대를, ...
# 2630    [이란, CBAM이란, 무엇인가요, 이란, 무엇, CBAM이란, 무엇인가요, 시계,...
# 2642    [뜻, trough가, 뜻이야, 무슨, 뜻, trough가, 무슨, 뜻이야, 태양열...
# 2647    [산업, 안전, 보건, 법, 보호대, 고용, 노무, 제공, 사람, 산업, 재해, 보...
# 2768    [•How, economies, scale, organization, time, m...
# 3264    [회기, 분석, 분석이, 가능한가, 회기, 분석, 분석이, 가능한가, 망간, 내식성...
# Name: Nouns, dtype: object

# %%
df_temp_3 = df_temp[df_temp['라벨'] == 3]
df3 = df_temp_3.groupby(['UserCode'])['Nouns'].sum()
df3
# Out:
# UserCode
# 79      [친환경, 강재, 위원회, 회장, 인사말, 줄, 정도, 작성, 강재, 위원회, 회장...
# 203     [회의, 참석, 메일, 호, 결산, 회의, hanseunghyuk, @, posco...
# 279     [공정, 담당자, 긴급, 생산, 요청, 메일, 작성, 긴급생산, 요청하는, 메일, ...
# 297     [탄소, 중립, 대해, ppt로, 만들어줘, 탄소, 중립, 대해, 로, 대해서, p...
# 473     [친환경, 이사회, 개회, 인사말, 작성, 개회식, 인사말, 작성해줘, 친환경, 이...
# 941     [해외, 고객, 초청, 영어, 이메일, 개략, 영문, 이메일, 초안, 작성, 고객사...
# 965     [소개, 대본, 작성, 대본, 자기, 소개, 대본, 작성, 대본, 원래, 전량, 수...
# 1780    [냉천, 범람, 포스코, 피해, 대응, 대한, 소감, 포스코, 피해대응에, 대한, ...
# 2384    [친환경, 강재, 위원회, 참석, 내빈, 대상, 위원회, 회장, 인사말, 참석하는,...
# 2385    [친환경, 에너지, 강재, 위원회, 이사회, 의장, 인사말, 격식, 작성, 이사회,...
# 2557    [대우조선, 해양, 포스코, 기술, 교류, 회, 인사, 멘트, 작성, 포스코의, 기...
# 2630    [고객, 체결, 시, 인사, 감사, 말, 안내, 부탁, MOU, 체결시, 인사, 감...
# 2642    [아래, 내용, 영어, 자연, 번역, 모든, 부서, 모든, 방법, 동원, 톤, 생산...
# 3147    [회의, 록, 회의록, 만들어줘, 회의, 록, 회의록, 만들어줘, 녹음, 거, 회의...
# 3253    [report, acquisition, Daewoo, Shipbuilding, Co...
# 3264    [뉴, 칼라, 이러닝, 워, 벤치, 교재, 확인, 예상, 문제, 개, Level2_...
# Name: Nouns, dtype: object

# %%
df_temp_5 = df_temp[df_temp['라벨'] == 5]
df5 = df_temp_5.groupby(['UserCode'])['Nouns'].sum()
df5
# Out:
# UserCode
# 203     [후판, 자동, 매매, 프로그램, 코딩, 자동매매, 프로그램, 코딩해죠, 후판, 자...
# 279     [엑셀, 중복, 항목, 삭제, 기능사, 용법, 중복된, 항목, 삭제하는, 기능사용법...
# 965     [문, 처럼, 파이썬, 언어, 기초, 구조, 단어, SQL문에, select, 처럼...
# 3264    [메일, 확인, 내용, 요약, 기능, 코딩, 확인하고, 내용을, 요약해주는, 기능을...
# Name: Nouns, dtype: object

# %%
# word_count_dict = {}

# for user_code, words in zip(df_temp['UserCode'], df_temp['Nouns']):
#     if user_code not in word_count_dict:
#         word_count_dict[user_code] = Counter()

#     word_count_dict[user_code].update(words)

# word_count_dict

# %%
df_freq = df_temp['UserCode'].value_counts().reset_index()
df_freq.columns = ['UserCode','Frequency']
df_freq
# Out:
#     UserCode  Frequency
# 0        203        619
# 1        965         86
# 2       2385         84
# 3        297         36
# 4         79         25
# 5       1372         17
# 6        473         17
# 7        279         14
# 8       3264         14
# 9        941         13
# 10      2642         13
# 11      1321         12
# 12      1780         12
# 13      3147          8
# 14      2557          7
# 15      2630          5
# 16      2457          5
# 17      2227          4
# 18      2384          3
# 19      3253          1
# 20      2624          1
# 21      2647          1
# 22      2768          1

# %%
df_user = df_temp.groupby('UserCode')['Nouns'].sum().reset_index()
df_user.columns = ['UserCode', 'Nouns']
df_user
# Out:
#     UserCode                                              Nouns
# 0         79  [포스코, 대해, 알, 내용, 알고, 있는, 내용, 포스코, 대해, 알, 내용, 설...
# 1        203  [회의, 참석, 메일, 호, 결산, 회의, hanseunghyuk, @, posco...
# 2        279  [공정, 담당자, 긴급, 생산, 요청, 메일, 작성, 긴급생산, 요청하는, 메일, ...
# 3        297  [대한민국, 풍력, 타워, 풍력, 타워, 대한민국, 풍력, 타워, 풍력, 타워, 대...
# 4        473  [이사회, 인사말, 인사말, 알려줘, 이사회, 인사말, 인사말, 알려줘, 친환경, ...
# 5        941  [price, plate, steel, price, plate, steel, 열교환...
# 6        965  [소개, 대본, 작성, 대본, 자기, 소개, 대본, 작성, 대본, 광양, 소, 탄소...
# 7       1321  [선박, 연료, 유, 종류, 연료유, 종류는, 선박, 연료, 유, 종류, 연료유, ...
# 8       1372  [주물, 제품, 종류, 만드는, 제품의, 종류를, 알려줘, 주물, 제품, 종류, 만...
# 9       1780  [=, y가, x는, =, y가, x는, =, y가, x는, =, 에서, y가, x...
# 10      2227  [difference, s355kl, s355kt, difference, s355k...
# 11      2384  [친환경, 강재, 위원회, 참석, 내빈, 대상, 위원회, 회장, 인사말, 참석하는,...
# 12      2385  [친환경, 에너지, 강재, 위원회, 이사회, 의장, 인사말, 격식, 작성, 이사회,...
# 13      2457  [포스코, 몇개, 몇개야, 포스코, 고로, 몇개, 고로, 몇개야, 몇개, POSCO...
# 14      2557  [선박, 엔진, 시장, 점유, 율, 대해, 시장, 점유율에, 알려주세요, 선박, 엔...
# 15      2624  [풍력발전, 용, 소재, 판매, 확대, 위햇, 활동, 요, 소재, 판매, 확대를, ...
# 16      2630  [고객, 체결, 시, 인사, 감사, 말, 안내, 부탁, MOU, 체결시, 인사, 감...
# 17      2642  [뜻, trough가, 뜻이야, 무슨, 뜻, trough가, 무슨, 뜻이야, 태양열...
# 18      2647  [산업, 안전, 보건, 법, 보호대, 고용, 노무, 제공, 사람, 산업, 재해, 보...
# 19      2768  [•How, economies, scale, organization, time, m...
# 20      3147  [회의, 록, 회의록, 만들어줘, 회의, 록, 회의록, 만들어줘, 녹음, 거, 회의...
# 21      3253  [report, acquisition, Daewoo, Shipbuilding, Co...
# 22      3264  [메일, 확인, 내용, 요약, 기능, 코딩, 확인하고, 내용을, 요약해주는, 기능을...

# %%
df_user = pd.merge(df_user,df_freq,on='UserCode')
df_user
# Out:
#     UserCode                                              Nouns  Frequency
# 0         79  [포스코, 대해, 알, 내용, 알고, 있는, 내용, 포스코, 대해, 알, 내용, 설...         25
# 1        203  [회의, 참석, 메일, 호, 결산, 회의, hanseunghyuk, @, posco...        619
# 2        279  [공정, 담당자, 긴급, 생산, 요청, 메일, 작성, 긴급생산, 요청하는, 메일, ...         14
# 3        297  [대한민국, 풍력, 타워, 풍력, 타워, 대한민국, 풍력, 타워, 풍력, 타워, 대...         36
# 4        473  [이사회, 인사말, 인사말, 알려줘, 이사회, 인사말, 인사말, 알려줘, 친환경, ...         17
# 5        941  [price, plate, steel, price, plate, steel, 열교환...         13
# 6        965  [소개, 대본, 작성, 대본, 자기, 소개, 대본, 작성, 대본, 광양, 소, 탄소...         86
# 7       1321  [선박, 연료, 유, 종류, 연료유, 종류는, 선박, 연료, 유, 종류, 연료유, ...         12
# 8       1372  [주물, 제품, 종류, 만드는, 제품의, 종류를, 알려줘, 주물, 제품, 종류, 만...         17
# 9       1780  [=, y가, x는, =, y가, x는, =, y가, x는, =, 에서, y가, x...         12
# 10      2227  [difference, s355kl, s355kt, difference, s355k...          4
# 11      2384  [친환경, 강재, 위원회, 참석, 내빈, 대상, 위원회, 회장, 인사말, 참석하는,...          3
# 12      2385  [친환경, 에너지, 강재, 위원회, 이사회, 의장, 인사말, 격식, 작성, 이사회,...         84
# 13      2457  [포스코, 몇개, 몇개야, 포스코, 고로, 몇개, 고로, 몇개야, 몇개, POSCO...          5
# 14      2557  [선박, 엔진, 시장, 점유, 율, 대해, 시장, 점유율에, 알려주세요, 선박, 엔...          7
# 15      2624  [풍력발전, 용, 소재, 판매, 확대, 위햇, 활동, 요, 소재, 판매, 확대를, ...          1
# 16      2630  [고객, 체결, 시, 인사, 감사, 말, 안내, 부탁, MOU, 체결시, 인사, 감...          5
# 17      2642  [뜻, trough가, 뜻이야, 무슨, 뜻, trough가, 무슨, 뜻이야, 태양열...         13
# 18      2647  [산업, 안전, 보건, 법, 보호대, 고용, 노무, 제공, 사람, 산업, 재해, 보...          1
# 19      2768  [•How, economies, scale, organization, time, m...          1
# 20      3147  [회의, 록, 회의록, 만들어줘, 회의, 록, 회의록, 만들어줘, 녹음, 거, 회의...          8
# 21      3253  [report, acquisition, Daewoo, Shipbuilding, Co...          1
# 22      3264  [메일, 확인, 내용, 요약, 기능, 코딩, 확인하고, 내용을, 요약해주는, 기능을...         14

# %%
df_user_rank = df_user.sort_values(by='Frequency',ascending=False)

# %%
df_user_rank5 = df_user_rank.head()

# %%
df_user_rank5
# Out:
#     UserCode                                              Nouns  Frequency
# 1        203  [회의, 참석, 메일, 호, 결산, 회의, hanseunghyuk, @, posco...        619
# 6        965  [소개, 대본, 작성, 대본, 자기, 소개, 대본, 작성, 대본, 광양, 소, 탄소...         86
# 12      2385  [친환경, 에너지, 강재, 위원회, 이사회, 의장, 인사말, 격식, 작성, 이사회,...         84
# 3        297  [대한민국, 풍력, 타워, 풍력, 타워, 대한민국, 풍력, 타워, 풍력, 타워, 대...         36
# 0         79  [포스코, 대해, 알, 내용, 알고, 있는, 내용, 포스코, 대해, 알, 내용, 설...         25

# %%
keywords_user = df_user_rank5[df_user_rank5['UserCode'] == 203]['Nouns']

# %%
keywords_user = list(keywords_user)[0]

# %%
len(keywords_user)
# Out:
# 82039

# %%
dict_words = dict()

for word in keywords_user:
    if word not in dict_words:
        dict_words[word] = 1
    else:
        dict_words[word] += 1

# %%
len(dict_words)
# Out:
# 5975

# %%
sorted_dict = dict(sorted(dict_words.items(), key=lambda x: x[1], reverse=True))
sorted_dict
# Out:
# {'기술': 1212,
#  '강': 942,
#  '포스코': 792,
#  '내용': 716,
#  '메일': 628,
#  '탱크': 614,
#  '용접': 598,
#  '및': 590,
#  '설계': 516,
#  '수정': 478,
#  '아래': 474,
#  '회': 462,
#  '진행': 450,
#  'LNG': 440,
#  '개발': 430,
#  '당사': 404,
#  '고Mn강': 402,
#  '후': 390,
#  '대한': 380,
#  '주': 376,
#  '%': 364,
#  '적용': 358,
#  '자료': 350,
#  '확인': 338,
#  '공사': 338,
#  '고': 336,
#  '당진': 316,
#  '교류': 308,
#  '가스': 300,
#  '부장': 296,
#  '현황': 292,
#  '수': 291,
#  '저장': 288,
#  '그룹': 282,
#  '한국': 282,
#  '검토': 274,
#  '에너지': 262,
#  '일정': 258,
#  '재료': 258,
#  '프로젝트': 248,
#  '위해': 248,
#  '고객': 244,
#  '시': 244,
#  '평가': 244,
#  '요청': 242,
#  '강재': 238,
#  '예정': 236,
#  '결과': 234,
#  '수주': 234,
#  '개선': 228,
#  '시장': 222,
#  '솔루션': 216,
#  '추가': 216,
#  '박사': 212,
#  '작성': 208,
#  '공유': 198,
#  '터미널': 196,
#  '구축': 192,
#  '한승혁': 190,
#  '대리': 190,
#  '것': 186,
#  '소개': 186,
#  '지원': 186,
#  '답변': 184,
#  '마케팅': 182,
#  '완료': 180,
#  '해외': 178,
#  '개최': 176,
#  '협의': 176,
#  '스마트': 172,
#  '등록': 170,
#  '수요': 170,
#  '산업': 168,
#  '조선': 168,
#  '안건': 164,
#  '계획': 160,
#  '김태욱': 160,
#  '설명': 158,
#  '보고': 158,
#  '발표': 158,
#  '단계': 158,
#  '회의': 154,
#  '감사합니다': 152,
#  '기술교류회': 150,
#  '관련': 150,
#  '제출': 148,
#  'Ni강': 146,
#  '부': 146,
#  '판매': 144,
#  '준비': 142,
#  '제공': 142,
#  '○': 142,
#  '플랜트': 140,
#  '건설': 138,
#  '망간': 136,
#  '제품': 136,
#  '초': 136,
#  '참석': 134,
#  '의견': 130,
#  '이종': 128,
#  '슬로건': 128,
#  '센터': 124,
#  '섹션': 124,
#  '박형진': 124,
#  '기술지원': 122,
#  '확보': 122,
#  '부서': 118,
#  '선정': 116,
#  '문의': 116,
#  '한국가스기술공사': 116,
#  '등재': 114,
#  '노동환': 114,
#  '사': 113,
#  '있는': 112,
#  '부탁드립니다': 112,
#  '질의': 112,
#  '위': 110,
#  '사항': 110,
#  '향후': 110,
#  '대해': 110,
#  '오후': 110,
#  '건': 110,
#  '수정해죠': 110,
#  '저장탱크': 108,
#  '안녕하십니까': 108,
#  '통해': 108,
#  '용강': 108,
#  '선언문': 108,
#  '함': 106,
#  '생산': 106,
#  '참고': 106,
#  '용접재료': 106,
#  '필요': 106,
#  '김상용': 104,
#  '용역': 102,
#  '재료선정': 102,
#  '현장': 102,
#  '후판': 100,
#  'LNG터미널': 100,
#  '고객사': 100,
#  '경우': 100,
#  '업무': 100,
#  '제작': 98,
#  '저온용강': 98,
#  '자동': 96,
#  '장소': 96,
#  '팀': 96,
#  '신뢰': 96,
#  '핫라인': 96,
#  '스마트하게': 94,
#  '더': 94,
#  '주문': 94,
#  '회사': 92,
#  '확대': 92,
#  '예상': 92,
#  '정리': 92,
#  '위한': 92,
#  '발주': 90,
#  ']': 90,
#  '㈜삼안': 90,
#  '공급': 88,
#  '슬': 88,
#  '설계용역': 88,
#  '재': 88,
#  '한준영': 88,
#  '보고서': 86,
#  '부탁': 86,
#  '금일': 86,
#  '용': 84,
#  '연구원': 84,
#  '→': 84,
#  '제안': 84,
#  '광양': 84,
#  '전망': 84,
#  '대하': 82,
#  '임원': 82,
#  '실': 82,
#  '친절하게': 82,
#  '드립니다': 82,
#  '업데이트': 82,
#  '방법': 80,
#  '별': 80,
#  '줄': 80,
#  '인증': 80,
#  '중': 78,
#  '참석자': 78,
#  '카운슬': 78,
#  '현재': 76,
#  '상황': 76,
#  '문서': 76,
#  '가능': 76,
#  '메일을': 76,
#  'steel': 74,
#  '준공': 74,
#  'P-건설': 74,
#  '기회': 74,
#  '비지니스': 74,
#  '품질': 74,
#  '봉': 74,
#  '등': 74,
#  '초저온부': 74,
#  '풍력': 72,
#  'PJT': 72,
#  '사례': 72,
#  '서울': 72,
#  '성분': 70,
#  '방안': 70,
#  '명': 70,
#  '적용을': 70,
#  '부분': 70,
#  '지역': 70,
#  '이슈': 68,
#  '시너지': 68,
#  '사용': 68,
#  '인력': 68,
#  '플랜트산업': 68,
#  '작성해죠': 68,
#  '이해': 68,
#  '차장': 68,
#  '통한': 68,
#  '검토서': 68,
#  '견학': 68,
#  '것이': 66,
#  'Ni': 66,
#  '포스코그룹': 66,
#  '석식': 66,
#  '수정해죠.안녕하세요': 66,
#  '송부': 66,
#  '기': 66,
#  '목적': 66,
#  '양사': 66,
#  '국가': 64,
#  '네트워크': 64,
#  '연구': 64,
#  '대응': 64,
#  '것으로': 64,
#  '고Mn': 64,
#  '착공': 64,
#  '선급': 64,
#  '요약': 64,
#  '참여': 62,
#  '설': 62,
#  '수직': 62,
#  'FCAW': 62,
#  '정기': 62,
#  '포함': 62,
#  '강의': 62,
#  '될': 62,
#  '도출': 60,
#  '기업': 60,
#  '신규': 60,
#  '협업': 60,
#  '관': 60,
#  '이상철': 60,
#  '안녕하세요': 60,
#  '회신': 60,
#  '기존': 60,
#  '일정을': 60,
#  '문제': 60,
#  '리포트': 58,
#  '용량': 58,
#  '개': 58,
#  '국내': 58,
#  '[': 58,
#  '한국어': 58,
#  '과제': 58,
#  '또한': 58,
#  '처럼': 58,
#  '검사': 58,
#  '측정': 58,
#  '월': 57,
#  '비교': 56,
#  '규격': 56,
#  '교육': 56,
#  '☞': 56,
#  '워크숍': 56,
#  '설비': 56,
#  '파트장': 56,
#  '덴마크': 56,
#  '구조': 54,
#  '철강': 54,
#  '할': 54,
#  '주요': 54,
#  '수석': 54,
#  '경제성': 54,
#  '광폭': 54,
#  '친환경': 54,
#  '따른': 54,
#  '수직자동용접': 54,
#  '추진': 54,
#  '전략': 54,
#  '발굴': 54,
#  '효과': 52,
#  '포스코건설': 52,
#  '첨부': 52,
#  '하반기': 52,
#  '/': 52,
#  '솔루션개발섹션': 52,
#  '국내외': 52,
#  '있어': 52,
#  '특성': 52,
#  '향상': 52,
#  '더욱': 52,
#  '강주': 52,
#  '조강주': 52,
#  '반영': 52,
#  '같습니다': 52,
#  '고려': 52,
#  '표면': 52,
#  '작업복': 52,
#  '비선형': 52,
#  '해상': 50,
#  '설치': 50,
#  '미팅': 50,
#  '안내': 50,
#  '일시': 50,
#  '협력': 50,
#  '수석연구원': 50,
#  '합니다': 50,
#  '메너': 50,
#  '직원': 50,
#  '지속': 50,
#  '전문가': 50,
#  '개척': 50,
#  '있도록': 48,
#  '유관': 48,
#  '국산': 48,
#  '과업': 48,
#  '계시': 48,
#  '프로모션': 48,
#  '하였습니다': 48,
#  '‘': 48,
#  '요량': 48,
#  '올해': 48,
#  '밀도': 48,
#  '만들어죠': 46,
#  '있을': 46,
#  '전달': 46,
#  '상세': 46,
#  '홀': 46,
#  '수소': 46,
#  '설득': 46,
#  '시공': 46,
#  '구축키로': 46,
#  '합의': 46,
#  '게': 46,
#  '제한': 46,
#  '전': 46,
#  '그렇게': 46,
#  '이': 45,
#  '저희': 45,
#  'Mn': 44,
#  '해': 44,
#  '경제': 44,
#  '소통': 44,
#  '이종관': 44,
#  '호기': 44,
#  '적용시': 44,
#  '내': 44,
#  '최종': 44,
#  '탄성': 44,
#  '계수': 44,
#  '미래': 44,
#  '초저온탱크기술센터': 44,
#  '단일': 44,
#  '인터': 42,
#  '외': 42,
#  '일시/장소': 42,
#  '예약': 42,
#  '있으며': 42,
#  '장님': 42,
#  'LNG저장탱크용': 42,
#  'KOCAS에': 42,
#  '교류회': 42,
#  '수요가': 42,
#  '사업': 40,
#  '베트남': 40,
#  '자료를': 40,
#  '코드': 40,
#  '내조': 40,
#  '조합': 40,
#  '연락': 40,
#  '정보': 40,
#  '여부': 40,
#  '매우': 40,
#  '고객사와': 40,
#  '내일': 40,
#  '설득적으로': 40,
#  '광폭재': 40,
#  '두께': 40,
#  '하는': 40,
#  '이광준': 40,
#  '획득': 40,
#  '대하여': 39,
#  '조사해': 38,
#  '소개자료': 38,
#  '효율': 38,
#  '목표': 38,
#  '연구소': 38,
#  '내용을': 38,
#  '하겠습니다': 38,
#  '메너있게': 38,
#  '협조': 38,
#  '하여': 38,
#  '수주에': 38,
#  '논의': 38,
#  '있습니다': 38,
#  '한화': 38,
#  '같이': 36,
#  '갯수': 36,
#  '진행현황': 36,
#  '동향': 36,
#  '활용': 36,
#  '처': 36,
#  '송도': 36,
#  '수정해죠.부장님': 36,
#  '이번': 36,
#  '방문': 36,
#  '실적': 36,
#  '길이': 36,
#  '인원': 36,
#  '예정입니다': 36,
#  '구축을': 36,
#  '시험': 36,
#  '투자': 36,
#  '그런': 36,
#  '를': 35,
#  '좀': 35,
#  '총': 34,
#  '분야': 34,
#  '한국어로': 34,
#  '주시': 34,
#  '앞': 34,
#  '오늘': 34,
#  '어제': 34,
#  '차': 34,
#  '필요성': 34,
#  'UT': 34,
#  '가지': 34,
#  'Test': 34,
#  '증가': 34,
#  '대한민국': 32,
#  '하고': 32,
#  'tank': 32,
#  '물산': 32,
#  '글로벌': 32,
#  'Steel': 32,
#  '가장': 32,
#  '상반기': 32,
#  '사전': 32,
#  '분': 32,
#  '말씀': 32,
#  '고망간강': 32,
#  '이상': 32,
#  '투입': 32,
#  '의견을': 32,
#  '강제': 32,
#  '검토서에': 32,
#  '수주를': 32,
#  '온도': 32,
#  '데이터': 32,
#  'Level': 32,
#  '제도': 32,
#  '인공': 32,
#  '중식': 32,
#  '부회장': 32,
#  '육상': 32,
#  'SAW': 32,
#  '이종용접': 32,
#  'LG': 32,
#  '면담': 32,
#  '모사': 32,
#  '양호': 32,
#  '때': 31,
#  '가격': 30,
#  '예산': 30,
#  '내식성': 30,
#  '프로그램': 30,
#  '적어죠': 30,
#  '발표자료': 30,
#  '이동': 30,
#  '이용': 30,
#  '문의가': 30,
#  '선택': 30,
#  '발전': 30,
#  '수정해죠.박사님': 30,
#  '전화': 30,
#  '있어서': 30,
#  '양성': 30,
#  '중심': 30,
#  '포항': 30,
#  '이상인': 30,
#  '질문': 30,
#  '탄성계수': 30,
#  'KOGAS에': 30,
#  '피로': 30,
#  '조사': 30,
#  '운영': 30,
#  '별도': 30,
#  '로': 29,
#  '호': 28,
#  '조사해죠': 28,
#  '최고': 28,
#  '임원카운슬': 28,
#  '접합': 28,
#  '간단하게': 28,
#  '감사하겠습니다': 28,
#  '조합과제': 28,
#  '있으시면': 28,
#  '소재': 28,
#  '발생': 28,
#  '사이즈': 28,
#  '새로운': 28,
#  '시기': 28,
#  '경제적': 28,
#  '혁신': 28,
#  '선': 28,
#  '방향': 28,
#  '섬': 28,
#  '해당': 28,
#  '입찰': 28,
#  'KOGAS': 28,
#  '수익': 28,
#  '값': 28,
#  '안': 28,
#  '파트': 28,
#  '정창환': 28,
#  '전력': 28,
#  '구조체': 28,
#  '기간': 28,
#  '강종': 26,
#  '발주처': 26,
#  'POSCO': 26,
#  '성능': 26,
#  '환경': 26,
#  '~': 26,
#  '확인을': 26,
#  '위하여': 26,
#  '항상': 26,
#  '노력': 26,
#  '설계시': 26,
#  '完': 26,
#  '관련하여': 26,
#  '유선': 26,
#  '에너지조선마케팅실': 26,
#  '짧게': 26,
#  '자동용접봉': 26,
#  'Slag/Spatter': 26,
#  'LNG탱크': 26,
#  '커뮤니케이션': 26,
#  '*': 26,
#  '다': 26,
#  '모든': 26,
#  '탄소': 26,
#  '중립': 26,
#  '안이': 26,
#  '이용기술': 26,
#  '제출키로': 26,
#  'A578': 26,
#  '사양': 26,
#  '아니라': 26,
#  '임': 26,
#  '있고': 26,
#  '보고를': 26,
#  '세아': 26,
#  '지금': 26,
#  '또': 26,
#  '작업': 26,
#  'High': 26,
#  '절차': 24,
#  '위해서는': 24,
#  '제조': 24,
#  '일': 24,
#  '관리': 24,
#  '배포': 24,
#  '컨설팅': 24,
#  'P-인터': 24,
#  'LNG저장탱크': 24,
#  '결정': 24,
#  'LIST': 24,
#  '포스코센터': 24,
#  '적극': 24,
#  '에너지조선': 24,
#  '결과를': 24,
#  '기술설명회': 24,
#  '삼안': 24,
#  '박사님': 24,
#  '같은': 24,
#  '>': 24,
#  '형식': 24,
#  '중요한': 24,
#  'Spec': 24,
#  '수신': 24,
#  '초안': 24,
#  '비교설계': 24,
#  '필요한': 24,
#  '정책': 24,
#  '고급': 24,
#  '예상됩니다': 24,
#  '그': 24,
#  '고Mn강의': 24,
#  '판매팀에': 24,
#  '크로스': 24,
#  '가공': 24,
#  '대상': 24,
#  '요약해죠': 24,
#  '지침': 24,
#  '국제': 24,
#  'modulus': 24,
#  'elasticity': 24,
#  '국제규격': 24,
#  '유봉': 24,
#  '답변서': 24,
#  '경쟁력': 24,
#  '김윤석': 24,
#  '이재환': 24,
#  'Energy': 24,
#  '획득하여': 24,
#  '비전': 24,
#  '작업성': 24,
#  '아세안': 24,
#  '해야': 22,
#  '아이디어': 22,
#  '전세계': 22,
#  '화': 22,
#  '접합연구그룹': 22,
#  '체크': 22,
#  '출장': 22,
#  '분석': 22,
#  '정도': 22,
#  '오전': 22,
#  '한번': 22,
#  '큰': 22,
#  '참고로': 22,
#  '이력': 22,
#  '번': 22,
#  '워드': 22,
#  '형식으로': 22,
#  '단어': 22,
#  '워크숍을': 22,
#  '하였으며': 22,
#  '안과': 22,
#  '효율적인': 22,
#  '이해도': 22,
#  '차세대': 22,
#  '세계': 22,
#  '수요량': 22,
#  '당사와': 22,
#  '포스코의': 22,
#  '인수': 22,
#  '있는지': 22,
#  'ASTM': 22,
#  'Anchor': 22,
#  '여러': 22,
#  'Review': 22,
#  '연결': 22,
#  '이야기': 22,
#  '장기': 22,
#  '안전': 22,
#  '열처리': 22,
#  '테크': 22,
#  '아이템': 22,
#  '중심으로': 22,
#  '항목': 22,
#  '부분들도': 22,
#  'material': 22,
#  '진출': 22,
#  'Innovation': 22,
#  '미래를': 22,
#  '고망간': 22,
#  '설명회': 21,
#  '선행': 20,
#  '부유': 20,
#  '실장': 20,
#  '공정': 20,
#  '제목': 20,
#  '최근': 20,
#  '최대': 20,
#  '성장': 20,
#  '대표': 20,
#  '여수': 20,
#  '다과': 20,
#  '음료수': 20,
#  '보고드립니다': 20,
#  '사항이': 20,
#  '부장님': 20,
#  '코': 20,
#  '마스터': 20,
#  '스마트하고': 20,
#  '당사는': 20,
#  '송도로': 20,
#  '업무에': 20,
#  '차주': 20,
#  '같은데': 20,
#  '참석하였습니다': 20,
#  '주시면': 20,
#  'SPEC': 20,
#  '적용하여': 20,
#  '효과에': 20,
#  'C': 20,
#  '공차': 20,
#  'CTOD': 20,
#  '넌': 20,
#  '작용': 20,
#  'Strap': 20,
#  '가스기술공사': 20,
#  '제품을': 20,
#  '보다': 20,
#  '서비스': 20,
#  '평탄': 20,
#  '문장': 20,
#  '향': 20,
#  '경쟁': 20,
#  '표준화': 20,
#  '실제': 20,
#  '나은': 20,
#  '두산': 20,
#  '것임': 20,
#  '센터장': 20,
#  '약': 20,
#  '인공섬': 20,
#  '개발한': 20,
#  '마련': 20,
#  '예정으로': 20,
#  '올해내': 20,
#  '로서': 20,
#  '최희암': 20,
#  '적용성': 20,
#  '전자': 19,
#  '조직': 18,
#  '어떻게': 18,
#  '삼성': 18,
#  '창': 18,
#  'Tank': 18,
#  '제철소': 18,
#  '금': 18,
#  '렌트': 18,
#  '담당자': 18,
#  '많이': 18,
#  '’': 18,
#  '주신': 18,
#  '메일로': 18,
#  '답변을': 18,
#  '용접부': 18,
#  '혹시': 18,
#  '황': 18,
#  '화요일': 18,
#  '감사': 18,
#  '도움': 18,
#  '하겠습니다.감사합니다': 18,
#  '필요합니다': 18,
#  '금주': 18,
#  '수요일': 18,
#  '교재': 18,
#  '주문사이즈': 18,
#  '됩니다': 18,
#  '제시': 18,
#  '도입': 18,
#  '양성을': 18,
#  '워크샵': 18,
#  '먼저': 18,
#  '역할': 18,
#  '유지': 18,
#  '개선이': 18,
#  '진행하였습니다': 18,
#  '대리이': 18,
#  '판단': 18,
#  '선박': 18,
#  '현대': 18,
#  '쪽': 18,
#  '분리': 18,
#  'B': 18,
#  '정리해죠': 18,
#  '저온': 18,
#  '비자': 18,
#  '극저온': 18,
#  '주제': 18,
#  '변화': 18,
#  '바탕': 18,
#  '교정': 18,
#  '부족': 18,
#  '영진': 18,
#  '착용': 18,
#  '고망간강의': 18,
#  '이해를': 18,
#  '엑셀': 18,
#  '해서': 18,
#  '자동차': 18,
#  '수준': 18,
#  '수요는': 18,
#  'STS': 18,
#  '기술리포트': 18,
#  '북유럽': 18,
#  '규모': 18,
#  '확보를': 18,
#  '제품의': 18,
#  '공급사로서': 18,
#  '표현': 18,
#  '가치': 18,
#  '사회': 18,
#  '다음': 17,
#  '한': 17,
#  '의': 17,
#  '서술': 16,
#  '업체': 16,
#  '활용한': 16,
#  '워': 16,
#  '니켈': 16,
#  '좋은': 16,
#  '많은': 16,
#  '자료배포': 16,
#  '플렌트산업': 16,
#  '공감': 16,
#  '비': 16,
#  '상황을': 16,
#  '준비가': 16,
#  '진행되고': 16,
#  '하기와': 16,
#  '공유를': 16,
#  '함께': 16,
#  'BOM과': 16,
#  'Project': 16,
#  '중에': 16,
#  '강관': 16,
#  '영업': 16,
#  '점': 16,
#  '성과': 16,
#  '기술자료': 16,
#  '당사의': 16,
#  '후속': 16,
#  '금요일': 16,
#  '아래와': 16,
#  '페이지': 16,
#  'pip': 16,
#  '드린': 16,
#  '차원': 16,
#  '가지기로': 16,
#  '기술설명': 16,
#  '업데이트가': 16,
#  '김용호': 16,
#  '스패터': 16,
#  '문제를': 16,
#  '개선을': 16,
#  '한글': 16,
#  '보내는': 16,
#  '풍력발전': 16,
#  '시스템': 16,
#  '정부': 16,
#  '인제': 16,
#  '거점': 16,
#  '발견': 16,
#  '문제나': 16,
#  '발견시': 16,
#  '제공사례': 16,
#  '도장': 16,
#  'PosMAC': 16,
#  '한국가스기술공사에서': 16,
#  '드립니다.확인': 16,
#  '드림': 16,
#  '최소': 16,
#  '경우는': 16,
#  '상무': 16,
#  '이사': 16,
#  'DNV': 16,
#  '이제': 16,
#  '얘기': 16,
#  '지정은': 16,
#  '이제부터': 16,
#  '주문서에서': 16,
#  '사향': 16,
#  '특성이': 16,
#  'API': 16,
#  '다른': 16,
#  '확장': 16,
#  '서관': 16,
#  '층': 16,
#  '티타임': 16,
#  '해결': 16,
#  '비용': 16,
#  '출하': 16,
#  '중공업': 16,
#  '논문': 16,
#  '가능성': 16,
#  '처리': 16,
#  '의사결정': 16,
#  '부식': 16,
#  'cost': 16,
#  '하면': 16,
#  '하이퐁': 16,
#  '제작사': 16,
#  '나올': 16,
#  '드릴': 16,
#  '표면품질': 16,
#  '워낙': 16,
#  '건조': 16,
#  '기지': 16,
#  '신흥': 16,
#  '증가할': 16,
#  '음향': 16,
#  '진법': 16,
#  '인장시험': 16,
#  '비자성': 16,
#  '음향공진법': 16,
#  '인장시험을': 16,
#  'CODE': 16,
#  '규격별': 16,
#  'TEST': 16,
#  'Cold': 16,
#  'Shearing': 16,
#  'Coating': 16,
#  'Fillet': 16,
#  'Weld': 16,
#  'Bending': 16,
#  'Gas': 16,
#  '벨기에': 16,
#  '조성': 16,
#  '가구': 16,
#  'Sea': 16,
#  '콘크리트': 16,
#  '모듈': 16,
#  '모듈러': 16,
#  '부유식': 16,
#  '인터내셔널': 16,
#  '진보': 16,
#  '삶': 16,
#  '동반': 16,
#  '이동성': 16,
#  '이노베이션': 16,
#  '일등': 16,
#  '동행': 16,
#  '향한': 16,
#  '삶의': 16,
#  '동반자로': 16,
#  '웹': 16,
#  '공동': 16,
#  '국외': 16,
#  '공성': 16,
#  '동등': 16,
#  '패널': 16,
#  '구간': 16,
#  '오버헤드': 16,
#  '중간': 16,
#  "'23.5.17": 16,
#  '新국산용접재료': 16,
#  '과': 15,
#  '하나': 15,
#  '찾아죠': 14,
#  '모지': 14,
#  '해상풍력': 14,
#  '방법을': 14,
#  'EPC': 14,
#  '해죠': 14,
#  '기술을': 14,
#  'status': 14,
#  '인도': 14,
#  '인구': 14,
#  '철': 14,
#  '수정해죠.안녕하십니까': 14,
#  '토론': 14,
#  '변경': 14,
#  '모색': 14,
#  '강재연구소': 14,
#  '메뉴': 14,
#  '수육': 14,
#  '리스트': 14,
#  '하시면': 14,
#  '언제든지': 14,
#  '정확한': 14,
#  '접수': 14,
#  '제가': 14,
#  '사실': 14,
#  '못': 14,
#  '저': 14,
#  '높은': 14,
#  '당사에': 14,
#  '조치': 14,
#  '참석이': 14,
#  '에너지조선소재마케팅실': 14,
#  '메시지': 14,
#  '<': 14,
#  '비즈니스': 14,
#  '수정해죠.향후': 14,
#  '계획으로는': 14,
#  '이전': 14,
#  '이전에': 14,
#  '반영하여': 14,
#  '※': 14,
#  '급': 14,
#  '초대': 14,
#  '풍력발전시스템': 14,
#  '아닌': 14,
#  '저희가': 14,
#  '해석': 14,
#  '이에': 14,
#  '답장': 14,
#  '기준': 14,
#  '모두': 14,
#  '초과': 14,
#  '예정일': 14,
#  '요구사항': 14,
#  ...}

# %%
words_remove = '박형진 한승혁 김태욱 노동환 내용 부장 강 아래 및 포스코'
elements_to_remove = set(words_remove.split())

# %%
filtered_dict = {key: value for key, value in dict_words.items() if key not in elements_to_remove}

# %%
import matplotlib.pyplot as plt
font_path = 'C:\Windows\WinSxS\amd64_microsoft-windows-f..uetype-malgungothic_31bf3856ad364e35_10.0.19041.1_none_bb40ebfb65874170/malgun.ttf' 
my_wc = wc(random_state=123,width=400,height=400,background_color='white',font_path=font_path)
img_wordcloud = my_wc.generate_from_frequencies(dict_words)

plt.figure(figsize = (10, 10)) # 크기 지정하기
plt.axis('off') # 축 없애기
plt.imshow(img_wordcloud) # 결과 보여주기

# %%
my_wc = wc(random_state=123,width=400,height=400,background_color='white',font_path=font_path)
img_wordcloud = my_wc.generate_from_frequencies(filtered_dict)

plt.figure(figsize = (10, 10)) # 크기 지정하기
plt.axis('off') # 축 없애기
plt.imshow(img_wordcloud) # 결과 보여주기

# %%
df_temp
# Out:
#       UserCode                                       UserQuestion  라벨  \
# 14         203  hanseunghyuk@posco.com으로 회의참석 메일 적어죠.2023.03.0...   3
# 29         203                                      Mn 시세를 찾고 싶은데   2
# 30         203                                       망간 시세를 찾고싶은데   2
# 31         203                        런던 금속 거래소에서 망간 가격 찾는 방법 알려죠   2
# 37         203                                     스테인리스 304 제작방버   2
# ...        ...                                                ...  ..
# 1863       473  ▣ 철강협회-중부발전-에넬엑스코리아 철강산업 탄소중립 및 재생에너지 확대를 위한 전...   3
# 1867      2385                  그룹장으로써 타의 모범이 되는 사례를 간략하게 작성해주세요.   2
# 1868      2385     \r\n그룹장으로써 리더십 관점에서 타의 모범이 되는 사례를 간략하게 작성해주세요.   2
# 1869      2385           리더로써 업무 비윤리 및 인간존중 등 윤리관련 우수 사항을 작성해주세요.   2
# 1871      2642   \r\n\r\n\r\n\r\nSl.No.\r\nDocuments\r\nRemark...   2
#
#                                                   Nouns
# 14    [회의, 참석, 메일, 호, 결산, 회의, hanseunghyuk, @, posco...
# 29         [시세, Mn, 시세를, 찾고, 싶은데, 시세, Mn, 시세를, 찾고, 싶은데]
# 30             [망간, 시세, 시세를, 찾고싶은데, 망간, 시세, 시세를, 찾고싶은데]
# 31    [런던, 금속, 거래소, 망간, 가격, 방법, 금속, 거래소에서, 망간, 가격, 찾...
# 37           [스테인리스, 제작, 방버, 제작방버, 스테인리스, 제작, 방버, 제작방버]
# ...                                                 ...
# 1863  [철강, 협회, 중부, 발전, 넬, 엑스, 코리아, 철강, 산업, 탄소, 중립, 재...
# 1867  [그룹, 타의, 모범, 사례, 작성, 타의, 모범이, 되는, 사례를, 간략하게, 작...
# 1868  [그룹, 리더십, 관점, 타의, 모범, 사례, 작성, 리더십, 관점에서, 타의, 모...
# 1869  [리더, 업무, 비, 윤리, 인간, 존중, 윤리, 관련, 우수, 사항, 작성, 업무...
# 1871  [Sl.No, Documents, Estimation, Corrosion, Rate...
#
# [998 rows x 4 columns]

# %%
user_203_labels_freq = df_temp[df_temp['UserCode'] == 203].groupby('라벨').size().reset_index(name='빈도')
user_203_labels_freq
# Out:
#    라벨   빈도
# 0   2  163
# 1   3  439
# 2   5   17

# %%
user_203_labels_freq['percentage'] = (user_203_labels_freq['빈도'] / user_203_labels_freq['빈도'].sum()) * 100

# %%
user_203_labels_freq
# Out:
#    라벨   빈도  percentage
# 0   2  163   26.332795
# 1   3  439   70.920840
# 2   5   17    2.746365

# %%
# keyword_for_qustions ={'status':set('현황 동향 시세 status current'.split()),
#                        'explanation':set('뜻 설명 mean explain 증명'.split()),
#                        'compare':set('비교 장점 단점 차이'.split()),
#                        'proposal':set('제시 방법 선정 방안'.split())}


# def q_status(text):
# Out:
#   Cell In[38], line 7
#     def q_status(text):
#                        ^
# SyntaxError: unexpected EOF while parsing

# %%
df2_q = df_temp[df_temp['라벨'] == 2][['UserCode','UserQuestion','Nouns']]
df2_q
# Out:
#       UserCode                                       UserQuestion  \
# 29         203                                      Mn 시세를 찾고 싶은데
# 30         203                                       망간 시세를 찾고싶은데
# 31         203                        런던 금속 거래소에서 망간 가격 찾는 방법 알려죠
# 37         203                                     스테인리스 304 제작방버
# 39         203                                      316L 성분 및 제조법
# ...        ...                                                ...
# 1856       965                 날판 설계를 할때 "매들이" 라는 단어가 무슨뜻인지 설명해줘
# 1867      2385                  그룹장으로써 타의 모범이 되는 사례를 간략하게 작성해주세요.
# 1868      2385     \r\n그룹장으로써 리더십 관점에서 타의 모범이 되는 사례를 간략하게 작성해주세요.
# 1869      2385           리더로써 업무 비윤리 및 인간존중 등 윤리관련 우수 사항을 작성해주세요.
# 1871      2642   \r\n\r\n\r\n\r\nSl.No.\r\nDocuments\r\nRemark...
#
#                                                   Nouns
# 29         [시세, Mn, 시세를, 찾고, 싶은데, 시세, Mn, 시세를, 찾고, 싶은데]
# 30             [망간, 시세, 시세를, 찾고싶은데, 망간, 시세, 시세를, 찾고싶은데]
# 31    [런던, 금속, 거래소, 망간, 가격, 방법, 금속, 거래소에서, 망간, 가격, 찾...
# 37           [스테인리스, 제작, 방버, 제작방버, 스테인리스, 제작, 방버, 제작방버]
# 39                   [성분, 제조법, 제조법, 성분, 및, 제조법, 및, 제조법]
# ...                                                 ...
# 1856  [날판, 설계, 단어, 뜻, 설계를, 매들이, 단어가, 무슨뜻인지, 날판, 설계, ...
# 1867  [그룹, 타의, 모범, 사례, 작성, 타의, 모범이, 되는, 사례를, 간략하게, 작...
# 1868  [그룹, 리더십, 관점, 타의, 모범, 사례, 작성, 리더십, 관점에서, 타의, 모...
# 1869  [리더, 업무, 비, 윤리, 인간, 존중, 윤리, 관련, 우수, 사항, 작성, 업무...
# 1871  [Sl.No, Documents, Estimation, Corrosion, Rate...
#
# [404 rows x 3 columns]

# %%
all_nouns_2 = [noun for nouns_list in df2_q['Nouns'] for noun in nouns_list]
word_frequencies = dict(Counter(all_nouns_2))

word_frequencies
# Out:
# {'시세': 4,
#  'Mn': 4,
#  '시세를': 4,
#  '찾고': 2,
#  '싶은데': 10,
#  '망간': 12,
#  '찾고싶은데': 2,
#  '런던': 2,
#  '금속': 4,
#  '거래소': 2,
#  '가격': 20,
#  '방법': 28,
#  '거래소에서': 2,
#  '찾는': 2,
#  '알려죠': 10,
#  '스테인리스': 2,
#  '제작': 10,
#  '방버': 2,
#  '제작방버': 2,
#  '성분': 4,
#  '제조법': 4,
#  '및': 58,
#  '포스코': 68,
#  '주식': 4,
#  '변동': 4,
#  '수치': 2,
#  '선행': 4,
#  '지표': 8,
#  '주식과': 2,
#  '변동하는': 2,
#  '수치는': 2,
#  '선행지표': 2,
#  '찾아죠': 14,
#  '같이': 1,
#  '그리고': 2,
#  '주식의': 2,
#  '변동지표': 2,
#  '선행지표는': 2,
#  '모지': 12,
#  '모': 6,
#  '원자재': 2,
#  '주가': 2,
#  '상관관계': 8,
#  '대하': 24,
#  '서술': 4,
#  '가격과': 2,
#  '주가의': 2,
#  '상관관계에': 2,
#  '서술하시오': 4,
#  '대하여': 11,
#  '대해': 42,
#  '알': 14,
#  '내용': 30,
#  '알고': 8,
#  '있는': 20,
#  '설명': 33,
#  '대해서': 16,
#  '설명해줘': 7,
#  'production': 2,
#  'capacity': 2,
#  'steel': 28,
#  'company': 6,
#  'posco': 2,
#  '회사': 20,
#  '조직': 22,
#  '구조': 30,
#  '계층': 8,
#  '수평': 4,
#  '장단점': 2,
#  '구조에서': 2,
#  '구조와': 2,
#  '수평적': 2,
#  '구조의': 2,
#  '장단점을': 2,
#  '기업': 14,
#  '시민': 2,
#  '는걸': 2,
#  '아는걸': 2,
#  '설명해주게나': 1,
#  '부유': 8,
#  '해상': 26,
#  '풍력': 62,
#  '자료': 22,
#  '해상풍력': 12,
#  '설명자료': 2,
#  '저장': 34,
#  '탱크': 50,
#  '대한': 98,
#  '대한민국': 40,
#  '터미널': 62,
#  '현황': 64,
#  '조사해': 38,
#  'LNG': 80,
#  '저장탱크에': 2,
#  '현황도': 2,
#  '조사해죠': 28,
#  '국가': 26,
#  '별': 30,
#  '암모니아': 4,
#  '업체': 20,
#  '저장탱크': 12,
#  '장보고': 2,
#  '장수': 2,
#  '함': 2,
#  '장수함에': 2,
#  '류': 4,
#  '승희': 4,
#  '사장': 2,
#  '류승희': 2,
#  '사장에': 2,
#  '류승희에': 2,
#  '소규모': 2,
#  '후판': 40,
#  '판매점': 2,
#  '판매점을': 2,
#  '하고': 2,
#  '방법을': 10,
#  '타워': 26,
#  '해상풍력타워': 6,
#  '정부': 2,
#  '제시': 2,
#  '출산율': 4,
#  '개선': 32,
#  '정책': 4,
#  '방안': 8,
#  '정부에서': 2,
#  '제시한': 2,
#  '말고': 4,
#  '방안은': 4,
#  '없을까': 6,
#  '다른': 5,
#  '좀더': 2,
#  '획기': 2,
#  '획기적인': 2,
#  '최적': 10,
#  '위치': 6,
#  '설치시': 2,
#  '최적의': 2,
#  '위치는': 2,
#  '어디지': 2,
#  '어디': 10,
#  '설치': 20,
#  '선정': 6,
#  '선정해죠': 2,
#  '남해': 4,
#  '서해': 4,
#  '동해': 4,
#  '어디에': 8,
#  '설치하는': 2,
#  '것이': 10,
#  '좋지': 2,
#  '중': 48,
#  '것': 37,
#  '철강': 34,
#  '생산': 26,
#  '공정은': 4,
#  '후판의': 4,
#  '있습니까': 6,
#  '어떤': 7,
#  '국제': 2,
#  '기구': 2,
#  '환경': 12,
#  '규제': 2,
#  '환경규제는': 2,
#  '입': 6,
#  'EURO': 2,
#  '무엇입니까': 2,
#  '무엇': 15,
#  'EU': 2,
#  'FIT': 2,
#  '내용입니까': 2,
#  '무슨': 10,
#  '메탄올': 6,
#  '추진': 10,
#  '선': 6,
#  '적용': 16,
#  '제품': 22,
#  '주요': 8,
#  '규격': 18,
#  '추진선에': 2,
#  '적용되는': 4,
#  '제품의': 4,
#  '규격은': 8,
#  '호': 2,
#  '중공업': 8,
#  '올해': 6,
#  '수주': 14,
#  '수주한': 8,
#  '메탄올추진선': 2,
#  '내용에': 8,
#  '알려주세요': 10,
#  '회의': 20,
#  '참석자': 6,
#  '확인': 32,
#  'forms으로': 2,
#  '확인하는': 4,
#  '기술': 46,
#  '교류': 10,
#  '회': 12,
#  '예산': 4,
#  '문의': 4,
#  '절차': 18,
#  '부서': 4,
#  '발전': 34,
#  '성능': 16,
#  '향상': 6,
#  '강재': 40,
#  '성능향상강재': 4,
#  '에너지': 24,
#  '스틸': 2,
#  '플라워': 2,
#  '관계': 6,
#  'CS에너지': 4,
#  '스틸플라워': 2,
#  '용': 12,
#  '풍력용': 2,
#  '윈드': 2,
#  'CS윈드에': 2,
#  'ㄷ대하여': 2,
#  '마케팅': 6,
#  '잘하기': 2,
#  '위해서는': 4,
#  '해야': 8,
#  '할까': 4,
#  '위': 12,
#  '어떻게': 8,
#  '갯수': 36,
#  '용량': 54,
#  '강종': 8,
#  'LNG터미널별': 8,
#  'tank': 16,
#  'inner': 6,
#  'shell': 6,
#  'EPC': 14,
#  '행사': 2,
#  '공시': 2,
#  '이슈': 6,
#  '사항': 20,
#  '시행사': 2,
#  '시공시': 2,
#  '이슈사항': 6,
#  '삼성': 4,
#  '물산': 4,
#  '프로젝트': 36,
#  'LNG터미널': 4,
#  '전세계': 50,
#  '진행': 14,
#  '예상': 26,
#  '준공': 10,
#  '발주': 10,
#  '처': 10,
#  '향후': 24,
#  '유통': 14,
#  '시장': 56,
#  'PJT': 12,
#  '진행현황': 10,
#  '준공일': 10,
#  '발주처': 10,
#  '저장탱크별': 10,
#  '유통시장': 10,
#  '일': 9,
#  '완공': 6,
#  '목표': 10,
#  '프로젝트를': 2,
#  '할': 16,
#  '수': 46,
#  '사이트': 12,
#  'Gastech': 2,
#  '사이트에서': 2,
#  'World': 4,
#  'Projects': 8,
#  'Status': 6,
#  'Report': 6,
#  'korea': 4,
#  'wind': 18,
#  'power': 2,
#  'Repor': 2,
#  'POSCO': 18,
#  '%': 8,
#  'Ni': 6,
#  '제철소': 16,
#  'Steel': 4,
#  '생산하는': 2,
#  'status': 14,
#  '공급': 4,
#  '인천': 8,
#  '사용': 24,
#  '탱크별': 2,
#  'supply': 2,
#  'materials': 6,
#  'suppliers': 4,
#  'tanks': 6,
#  'Incheon': 6,
#  'Terminal': 6,
#  '고객': 24,
#  '미팅': 12,
#  '결과': 12,
#  '보고서': 8,
#  'Gs에너지': 2,
#  '고객사': 12,
#  '결과보고서': 2,
#  '사': 10,
#  '최근': 42,
#  '최대': 34,
#  '강수량': 4,
#  '최고': 6,
#  '기온': 2,
#  'La': 2,
#  '최고기온': 2,
#  '픽업': 2,
#  '트럭': 2,
#  '소요량': 8,
#  '한대': 2,
#  '브레인': 4,
#  '멤브레인': 2,
#  '워': 6,
#  '벤치': 2,
#  '파이썬': 2,
#  '비교': 16,
#  '파이썬을': 2,
#  '비교해서': 2,
#  '설명해죠': 4,
#  '뒤': 4,
#  '인도': 16,
#  '경제': 16,
#  '성장': 20,
#  '리포트': 16,
#  '인도의': 2,
#  '성장에': 4,
#  '베트남': 8,
#  '베트남의': 4,
#  '인구': 18,
#  '평균': 12,
#  '연령': 8,
#  '증명': 8,
#  '상관관계를': 6,
#  '증명해봐': 6,
#  '내식성': 28,
#  'Ni과': 2,
#  '과': 7,
#  '니켈': 4,
#  '분과': 2,
#  '가장': 40,
#  '자동': 4,
#  '접기': 2,
#  '추천': 2,
#  '좋은': 2,
#  '용접기': 2,
#  '추천해죠': 2,
#  '리스크': 2,
#  '관리': 22,
#  '관리에': 2,
#  '현재': 12,
#  '터빈': 16,
#  '정도': 4,
#  '설치된': 4,
#  '용량이': 4,
#  '큰게': 2,
#  '몇MW정도야': 2,
#  '몇': 8,
#  '기준': 6,
#  '큰': 8,
#  '것은': 28,
#  'vestas': 6,
#  '것으로': 2,
#  '있는데': 4,
#  '실증': 4,
#  '부탁': 8,
#  '알고있어': 2,
#  '부탁해': 2,
#  '중으로': 2,
#  'ㅇ알고있어': 2,
#  'ㅂ부탁해': 2,
#  '무게': 4,
#  '무게를': 2,
#  '싶어': 2,
#  '개발': 54,
#  '한계': 8,
#  '일지': 8,
#  '논문': 6,
#  '터빈의': 4,
#  '한계는': 4,
#  '어디까지': 4,
#  '가능한': 6,
#  '자세하고': 6,
#  '길게': 6,
#  '논문처럼': 6,
#  '써줘': 4,
#  '더': 22,
#  '자세히': 2,
#  '써주세요': 2,
#  '하부구조': 6,
#  '물이': 2,
#  '관련': 20,
#  '용도': 2,
#  '추가': 4,
#  '관련내용도': 2,
#  '추가해주세요': 2,
#  '물': 4,
#  '종류': 8,
#  '하부구조물에': 2,
#  '강재의': 2,
#  '종류에': 2,
#  '물의': 2,
#  '대략': 2,
#  '하부구조물의': 2,
#  '대략적인': 2,
#  '무게는': 2,
#  '되나요': 2,
#  '한국': 14,
#  '전망': 16,
#  '최대한': 8,
#  '분석': 8,
#  '디테': 4,
#  '풍력시장': 2,
#  '전망을': 4,
#  '분석해줘': 2,
#  '정말정말': 2,
#  '디테일하게': 2,
#  '하나하나': 2,
#  '이상으로': 4,
#  '하나': 6,
#  '이상': 17,
#  '알려줘': 34,
#  '발전기': 2,
#  '터빈발전기': 2,
#  '개발현황': 2,
#  '두산': 12,
#  '풍력발전': 4,
#  'ㅍ풍력발전': 2,
#  'ㅎ현황': 2,
#  '티': 4,
#  '이름': 4,
#  '두산에너빌리티로': 2,
#  '바꿨어': 2,
#  '너': 2,
#  '계열': 2,
#  '두산에너지라는': 4,
#  'ㄱ계열사가있어': 2,
#  '다시': 2,
#  '한번': 2,
#  '조사': 34,
#  '회사가': 2,
#  '없어': 4,
#  'ㄷ다시한번': 2,
#  '조사해봐': 2,
#  '그룹': 10,
#  '시너지': 6,
#  '대표': 4,
#  '사례': 8,
#  '시너지를': 2,
#  '낸': 2,
#  '도출': 2,
#  '도출방안': 2,
#  '적어죠': 2,
#  '세계': 14,
#  '아주': 4,
#  '부유식': 2,
#  '조사해줘': 10,
#  '자': 1,
#  '고정식': 2,
#  '차이점': 4,
#  '부유식해상풍력과': 2,
#  '고정식해상풍력의': 2,
#  '차이점은': 2,
#  'ㅇ알고': 2,
#  'ㅇ있니': 2,
#  '확인해죠': 6,
#  '출장': 8,
#  '이동': 4,
#  '동선': 2,
#  '일정': 12,
#  '오후': 10,
#  '센터': 12,
#  '출발': 2,
#  '도착': 2,
#  '참석': 2,
#  '점심': 4,
#  '식사': 2,
#  '복귀': 4,
#  '동선하고': 2,
#  '포스코센터': 2,
#  'r': 2,
#  'd': 1,
#  '기술교류회': 6,
#  '센터로': 2,
#  '송도': 4,
#  '대중교통': 4,
#  '코스': 4,
#  '포스코R': 2,
#  'D센터': 2,
#  '카본파이버': 2,
#  '철': 6,
#  '대체': 2,
#  '철을': 2,
#  '대체할수': 2,
#  '있을까': 8,
#  '재활용': 4,
#  '소개': 8,
#  '소개의': 2,
#  '차이점이': 2,
#  '이용': 4,
#  '멱': 2,
#  'Chatgpt을': 2,
#  '이용하고': 2,
#  '싶으멱': 2,
#  'teams을': 2,
#  '설치하면': 2,
#  '되는거야': 2,
#  'market': 4,
#  '설계': 32,
#  '획': 2,
#  'samaneng': 4,
#  '획인해죠': 2,
#  '주': 28,
#  '소개해죠': 2,
#  '이송': 2,
#  '강관': 4,
#  '용접': 48,
#  '부': 8,
#  '특성': 4,
#  '용접부': 6,
#  '해봐': 2,
#  'ETF가': 2,
#  '수출': 8,
#  '선박': 10,
#  'FIBT와': 4,
#  'FIO에': 2,
#  '포트': 2,
#  '별로': 2,
#  '차이': 4,
#  '포트별로': 2,
#  'FIO': 2,
#  '차이가': 2,
#  '있는건': 2,
#  '왜지': 2,
#  '왜': 1,
#  '친환경': 14,
#  '실적': 6,
#  '등록': 2,
#  '포스코건설': 2,
#  '플랜트': 6,
#  '화': 2,
#  '준비': 8,
#  '발표': 2,
#  '수합': 2,
#  '후': 48,
#  '보고': 6,
#  '조선': 6,
#  '카운슬': 4,
#  '안내': 4,
#  '메일': 6,
#  '발송': 2,
#  '예정': 10,
#  '금': 4,
#  '업무': 26,
#  '계획': 2,
#  '산업': 18,
#  '작성': 26,
#  '당진': 4,
#  '호기': 2,
#  '후속': 4,
#  '조치': 6,
#  '금주': 4,
#  '자문': 2,
#  '지원': 10,
#  '이종': 2,
#  '관': 2,
#  '박사': 4,
#  '실적등록': 2,
#  '完': 6,
#  '발표자료': 2,
#  '~3.13/월': 2,
#  '보고3': 2,
#  '에너지조선': 2,
#  '→': 2,
#  '메일발송': 2,
#  '플랜트산업': 4,
#  '수주에': 2,
#  '따른': 6,
#  '☞': 2,
#  '기술자문': 2,
#  '월': 1,
#  '수입': 2,
#  '수익': 4,
#  '개념': 4,
#  '수익은': 2,
#  '같은': 2,
#  '개념인가요': 2,
#  'PosMac': 2,
#  '비교해죠': 6,
#  'PosMac과': 2,
#  'SUS304': 4,
#  'PosMac3.0과': 2,
#  '낼': 4,
#  '콜라보': 8,
#  '비지니스': 6,
#  '삼성물산': 2,
#  'LNG산업에서': 2,
#  '이루어': 2,
#  '비지니스는': 2,
#  '대우조선': 4,
#  '해양': 4,
#  '대우조선해양': 4,
#  '수소': 10,
#  '설': 6,
#  '계시': 6,
#  '설계시': 6,
#  '중요한': 4,
#  'price': 2,
#  'plate': 2,
#  '태양광': 60,
#  '최신': 12,
#  '정보': 12,
#  '산업에': 2,
#  '정보가': 2,
#  '올라오는': 2,
#  '태양': 4,
#  '량': 4,
#  '신규': 8,
#  '태양량': 2,
#  '설치량': 2,
#  'RELIANCE': 4,
#  '유사한': 2,
#  '와': 1,
#  '사업': 24,
#  '사업에': 2,
#  '연료': 4,
#  '유': 4,
#  '연료유': 2,
#  '종류는': 2,
#  '앞': 2,
#  '유망': 2,
#  '연료유는': 2,
#  '어떤것이': 2,
#  '유망할까': 2,
#  '그린': 2,
#  '메탄올은': 2,
#  '만드는': 4,
#  '것인가요': 2,
#  '최고의': 2,
#  '업체는': 4,
#  '단일': 4,
#  '공장': 4,
#  '공장으로': 2,
#  '선용': 2,
#  '공장은': 2,
#  'CBAM': 2,
#  '주물': 6,
#  '종류를': 2,
#  '네모': 6,
#  '모양': 4,
#  '모양의': 2,
#  '주물제품을': 2,
#  '알려': 4,
#  '줘': 4,
#  '기계': 20,
#  '부품': 6,
#  '모양인': 2,
#  '부품을': 2,
#  '리트': 2,
#  '핏': 2,
#  '리트로핏': 2,
#  '수에즈': 2,
#  '막스': 2,
#  '탱커': 4,
#  '수에즈막스': 2,
#  '선사': 2,
#  '합병': 2,
#  '시': 12,
#  '결합': 2,
#  '승인': 2,
#  '국': 2,
#  '합병시': 2,
#  '기업결합': 2,
#  '승인국': 2,
#  '방법은': 4,
#  '빌게이츠': 2,
#  '부정합': 2,
#  '제철소에서': 2,
#  '빌게이츠의': 2,
#  '원자료를': 2,
#  '적용하는': 2,
#  '부정합하다고': 2,
#  '증명해죠': 2,
#  '원자': 2,
#  '제철소에': 2,
#  '원자를': 2,
#  '설치하기': 2,
#  '해야하지': 2,
#  '원자로': 2,
#  '용강': 2,
#  '단계': 16,
#  'LNG저장탱크용': 2,
#  '저온용강': 2,
#  '※': 2,
#  '삼안': 2,
#  '설계수주': 2,
#  '설명회': 1,
#  '광양': 4,
#  '소': 2,
#  '탄소강': 8,
#  '날판': 12,
#  '실수': 4,
#  '율': 8,
#  '대로': 2,
#  '유지': 2,
#  '게': 6,
#  '유지되고': 2,
#  '어떻게하면': 2,
#  '실수율을': 2,
#  '높일': 6,
#  '약호': 4,
#  '홍콩': 12,
#  '판매': 14,
#  '톤': 4,
#  '영업': 8,
#  '원가': 8,
#  '이익': 4,
#  'EN-S355J0AR': 10,
#  'EN-S275J0AR로': 4,
#  'KYH로': 4,
#  '가격을': 8,
#  '오퍼하려하는데': 4,
#  '포스코에서': 2,
#  '수출되는': 2,
#  'EN-S275J0AR': 2,
#  'BASE판매가격': 2,
#  '톤당': 2,
#  '영업원가': 2,
#  '톤당영업이익': 2,
#  '영업이익율을': 2,
#  '알려줘\\': 2,
#  '로': 9,
#  '님': 4,
#  '프로필': 6,
#  '사진': 6,
#  'chatGPT': 6,
#  '님의': 2,
#  '사진입니다.규격약호': 2,
#  '홍콩에서': 4,
#  '유통되는': 4,
#  'EN-S275J0AR의': 4,
#  '의': 15,
#  '조회': 2,
#  '조회할': 2,
#  '발행': 2,
#  '발행된': 2,
#  '주물지를': 2,
#  '받아보고': 2,
#  '책': 2,
#  '제작하는': 2,
#  '절차는': 2,
#  '강': 28,
#  '고Mn강이란': 2,
#  '고': 10,
#  '강의': 4,
#  '특징': 4,
#  '고Mn강의': 4,
#  '단점': 8,
#  'diadventage': 2,
#  '채팅': 2,
#  '방': 2,
#  '번역': 2,
#  'teams': 2,
#  '하지': 6,
#  '검사': 6,
#  'UT검사': 2,
#  'A578': 6,
#  'levelC': 2,
#  '업무절차': 2,
#  'V42JPB3은': 2,
#  '쓰이는': 14,
#  '강재이니': 6,
#  '은': 5,
#  'Anchor': 2,
#  'Strap이': 2,
#  '이': 3,
#  'V42JPB3의': 8,
#  '차이는': 12,
#  '무엇이니': 6,
#  '열처리': 18,
#  '생략': 2,
#  '열처리를': 2,
#  '생략하냐': 2,
#  '안하냐의': 2,
#  '차이만': 2,
#  '있는거지': 2,
#  '다르지': 2,
#  '않은거야': 2,
#  '걸': 2,
#  '압': 6,
#  '추출': 2,
#  '온도': 2,
#  '통과': 2,
#  '공정': 2,
#  '동일한걸': 2,
#  '사용하고': 4,
#  '있고': 2,
#  '압하비': 2,
#  '압연추출온도': 2,
#  '통과공정': 2,
#  '동일해': 2,
#  '모두': 4,
#  '메너': 2,
#  '미팅시': 2,
#  '메너에': 2,
#  'DNV': 10,
#  'Plate': 10,
#  'A': 1,
#  'grade': 2,
#  'test': 14,
#  'plan': 10,
#  'LT-FH51': 4,
#  'CTOD': 4,
#  'LT-F51': 4,
#  'COD': 2,
#  'UT': 2,
#  '선생님': 4,
#  '부탁드립니다': 2,
#  'SAGD': 4,
#  'X80': 4,
#  '말': 4,
#  '말해줘': 2,
#  '규모': 10,
#  '탄화': 4,
#  '발전소': 4,
#  '규모의': 4,
#  '석탄화력': 4,
#  '발전소는': 4,
#  'MW인가요': 6,
#  '초임': 2,
#  '보일러': 2,
#  '부탁합니다': 2,
#  '가스터빈': 4,
#  '제작이': 2,
#  '국가들은': 2,
#  '가스터빈은': 2,
#  'API': 2,
#  '열교환기': 2,
#  '응기': 2,
#  '반응기는': 2,
#  '프로젝트에서': 2,
#  '사용되나요': 2,
#  '복합': 2,
#  '화력발전소': 6,
#  '기자': 2,
#  '재는': 2,
#  '기자재는': 2,
#  '것들이': 2,
#  '있나요': 6,
#  '스팀': 6,
#  '드럼': 6,
#  '무엇이며': 2,
#  '생겼나요': 2,
#  '무었': 4,
#  '스팀드럼은': 2,
#  '무었인가요': 2,
#  '스팀드럼': 2,
#  '사진을': 2,
#  '확인하고싶어요': 2,
#  '관사': 4,
#  '리스트': 12,
#  '강관사': 4,
#  '리스트를': 2,
#  '알수있을까요': 2,
#  '아시아': 2,
#  '지역': 2,
#  '지역의': 2,
#  'Big': 2,
#  'Pipe': 2,
#  'mills': 2,
#  'Asia': 2,
#  '설비': 4,
#  '폐쇄': 2,
#  '일본': 4,
#  '열처리설비를': 2,
#  '폐쇄한': 2,
#  '일본의': 2,
#  '철강사는': 2,
#  '폐쇄했다': 2,
#  '이유': 4,
#  '철강회사가': 2,
#  '설비를': 2,
#  '폐쇄했다고': 2,
#  '들었습니다': 2,
#  '그이유는': 2,
#  '무엇인가요': 6,
#  '해외': 12,
#  '작전': 2,
#  '얘기': 2,
#  '어회': 2,
#  '고객사와': 2,
#  '기술미팅이': 2,
#  '예정되어있습니다': 2,
#  '간단히': 4,
#  '얘기할수있는': 2,
#  '영어회화를': 2,
#  'difference': 4,
#  's355kl': 2,
#  's355kt': 2,
#  '넌': 4,
#  '이제': 4,
#  '실': 4,
#  '직원': 8,
#  '신수': 4,
#  '다이어트': 4,
#  '이제부터': 4,
#  '마케팅실': 4,
#  '직원이야.신수요': 4,
#  '업무에서': 4,
#  '워크다이어트': 4,
#  '아이디어': 4,
#  '개': 6,
#  '만들어죠': 6,
#  'marketing': 6,
#  'department': 2,
#  'employee': 2,
#  'work': 8,
#  'ideas': 4,
#  'acceptance': 4,
#  'development': 6,
#  'outlook': 2,
#  'copilot를': 2,
#  '를': 4,
#  '전문가': 4,
#  '문제점': 2,
#  '해결': 2,
#  '전략': 4,
#  '형': 10,
#  '발굴': 12,
#  '위해': 30,
#  '확대': 6,
#  '심층': 4,
#  '인터뷰': 4,
#  '전문': 2,
#  '기관': 2,
#  '활용': 10,
#  '작년': 2,
#  '제도': 16,
#  '운영': 4,
#  '효율': 8,
#  '활동': 6,
#  '점': 2,
#  '제품개발의': 2,
#  '문제점을': 2,
#  '이끌어': 2,
#  '내고': 2,
#  '해결방안을': 2,
#  'Demand': 2,
#  'Pull형': 2,
#  '발굴을': 4,
#  '위한': 12,
#  '시장/고객니즈': 2,
#  '전문기관': 2,
#  '시장성': 2,
#  '제품을': 6,
#  'Market': 2,
#  'Supreme': 2,
#  '중인데': 2,
#  '효율적인': 4,
#  '활동이': 4,
#  '되려면': 2,
#  '점을': 2,
#  '개선해야': 2,
#  '하는지': 2,
#  '등': 14,
#  '좀': 4,
#  '회장': 2,
#  '경기': 2,
#  '점점': 4,
#  '절감': 2,
#  '요청': 10,
#  '꼭': 4,
#  '가라': 2,
#  '지시': 2,
#  '효과': 4,
#  '회장처럼': 2,
#  '경기가': 2,
#  '안좋아지고': 2,
#  '있어': 2,
#  '원가절감을': 2,
#  '요청했고': 2,
#  '출장도': 2,
#  '필요한': 4,
#  '출장만': 2,
#  '가라고': 2,
#  '했어': 2,
#  '향상을': 2,
#  '개발하고': 2,
#  '판매하라고': 2,
#  '지시했고': 2,
#  '효과가': 4,
#  '추가로': 2,
#  '무엇을': 2,
#  '그런데': 1,
#  '더욱': 8,
#  '수행': 2,
#  '프로세스': 10,
#  '재': 2,
#  ...}

# %%
dfff = pd.DataFrame(list(word_frequencies.items()), columns=['Word', 'Frequency'])

excel_file_path = "word_frequencies.xlsx"
dfff.to_excel(excel_file_path, index=False)

# %%
data_path = '../data/'
filename = 'keywords_2_esm.xlsx'

df_keyword_2 = pd.read_excel(data_path + filename)

df_keyword_2
# Out:
#          words  frequency
# 0          LNG         80
# 1           풍력         62
# 2          터미널         62
# 3          태양광         60
# 4           탱크         50
# ..         ...        ...
# 216     Hybrid          2
# 217  Hydrogen에          2
# 218       MSDS          2
# 219       Mill          2
# 220      ZM275          2
#
# [221 rows x 2 columns]

# %%
keyword_set = set(df_keyword_2['words'].tolist())
keyword_set
# Out:
# {'A578',
#  'BIS20P',
#  'BIS20TP',
#  'CBAM',
#  'CBAM이란',
#  'COD',
#  'CTOD',
#  'DNV',
#  'DQT',
#  'EN-S275J0AR로',
#  'EN-S275J0AR의',
#  'EN-S355J0AR',
#  'ETF가',
#  'FIO',
#  'FIO에',
#  'HQs',
#  'Hybrid',
#  'Hydrogen에',
#  'LCO2',
#  'LNG',
#  'LNG저장탱크용',
#  'LNG탱크',
#  'LNG터미널',
#  'LNG터미널별',
#  'LR은',
#  'LT-F51',
#  'LT-FH51',
#  'LTFH36',
#  'MODULE',
#  'MSDS',
#  'Mill',
#  'Mn',
#  'Ni',
#  'Ni과',
#  'P690',
#  'PJT',
#  'Pipe',
#  'Plate',
#  'PosMAC은',
#  'PosMac',
#  'PosMac3.0과',
#  'PosMac과',
#  'QT',
#  'SAGD',
#  'SSAB',
#  'SSAB의',
#  'STS',
#  'STS304',
#  'SUS304',
#  'Solar',
#  'Steel',
#  'Strap이',
#  'UT',
#  'UT검사',
#  'V42JPB3은',
#  'V42JPB3의',
#  'X80',
#  'ZM275',
#  'Zinc',
#  'blast',
#  'coil',
#  'fabricator',
#  'fresnel이',
#  'furnaces',
#  'heliostat가',
#  'hydrogen',
#  'lng',
#  'lng터미널',
#  'manufacture',
#  'plate',
#  'rust',
#  's355kl',
#  's355kt',
#  'solar',
#  'steel',
#  'stirling이',
#  'surface',
#  'tank',
#  'tanks',
#  'trough가',
#  'zinc',
#  '가공',
#  '가스터빈',
#  '가스터빈은',
#  '강',
#  '강관',
#  '강재',
#  '강재개발',
#  '강재소요량에',
#  '강재의',
#  '강종',
#  '거칠기와',
#  '고Mn강',
#  '고Mn강의',
#  '고Mn강이란',
#  '고로',
#  '고로가',
#  '고망간',
#  '고정식해상풍력의',
#  '공정',
#  '공정은',
#  '구조물용',
#  '구조재용',
#  '규격',
#  '금속',
#  '기계',
#  '내구성에',
#  '내식성',
#  '내식성을',
#  '내피로강',
#  '니켈',
#  '도장',
#  '도장의',
#  '도장이',
#  '디스크',
#  '디스크의',
#  '리트로핏',
#  '막스',
#  '망간',
#  '메탄올',
#  '메탄올은',
#  '메탄올추진선',
#  '멤브레인',
#  '물질',
#  '반응기는',
#  '발전소',
#  '발전소는',
#  '보일러',
#  '부유식해상풍력과',
#  '부정합',
#  '선박',
#  '성능향상강재',
#  '소재',
#  '소재는',
#  '수소',
#  '수에즈',
#  '수에즈막스',
#  '스테인리스',
#  '스틸',
#  '스틸플라워',
#  '스팀드럼',
#  '스팀드럼은',
#  '압연추출온도',
#  '압하비',
#  '엔진',
#  '연료유',
#  '연료유는',
#  '연마',
#  '연마하거나',
#  '열교환기',
#  '열처리',
#  '열처리를',
#  '열처리설비를',
#  '온도',
#  '용강',
#  '용삭',
#  '용접',
#  '용접부',
#  '용접부의',
#  '용접속도와',
#  '용접재료',
#  '운반선',
#  '원자로',
#  '입열량을',
#  '저온용강',
#  '저장탱크',
#  '저장탱크별',
#  '저장탱크에',
#  '제철소',
#  '제철소에',
#  '제철소에서',
#  '조선',
#  '조재용',
#  '주물',
#  '주물제품을',
#  '지붕형',
#  '지석검사에',
#  '철',
#  '철강',
#  '초연결',
#  '추출',
#  '카본파이버',
#  '코일',
#  '타워',
#  '탄소',
#  '탄소강',
#  '태양광',
#  '태양광에',
#  '태양광패널',
#  '태양열',
#  '탱크',
#  '탱크별',
#  '터미널',
#  '터빈',
#  '터빈의',
#  '통과공정',
#  '패널',
#  '표면',
#  '표면은',
#  '표면의',
#  '표층',
#  '풍력',
#  '풍력발전',
#  '풍력용',
#  '풍력타워',
#  '프레임',
#  '플라워',
#  '피로',
#  '피로균열',
#  '피로균열을',
#  '피로균열이',
#  '피로성능',
#  '피로성능을',
#  '피로에',
#  '하부구조물의',
#  '해상',
#  '해상풍력',
#  '해상풍력타워',
#  '황',
#  '후판',
#  '후판의'}

# %%
def keyword_in_question(text_list):
    nouns = set(text_list)
    if len(nouns.intersection(keyword_set)):
        return 1
    else:
        return 0

# %%
df2_q['KeywordUsed'] = df2_q['Nouns'].apply(lambda x: keyword_in_question(x))
df2_q
# Out:
#       UserCode                                       UserQuestion  \
# 29         203                                      Mn 시세를 찾고 싶은데
# 30         203                                       망간 시세를 찾고싶은데
# 31         203                        런던 금속 거래소에서 망간 가격 찾는 방법 알려죠
# 37         203                                     스테인리스 304 제작방버
# 39         203                                      316L 성분 및 제조법
# ...        ...                                                ...
# 1856       965                 날판 설계를 할때 "매들이" 라는 단어가 무슨뜻인지 설명해줘
# 1867      2385                  그룹장으로써 타의 모범이 되는 사례를 간략하게 작성해주세요.
# 1868      2385     \r\n그룹장으로써 리더십 관점에서 타의 모범이 되는 사례를 간략하게 작성해주세요.
# 1869      2385           리더로써 업무 비윤리 및 인간존중 등 윤리관련 우수 사항을 작성해주세요.
# 1871      2642   \r\n\r\n\r\n\r\nSl.No.\r\nDocuments\r\nRemark...
#
#                                                   Nouns  KeywordUsed
# 29         [시세, Mn, 시세를, 찾고, 싶은데, 시세, Mn, 시세를, 찾고, 싶은데]            1
# 30             [망간, 시세, 시세를, 찾고싶은데, 망간, 시세, 시세를, 찾고싶은데]            1
# 31    [런던, 금속, 거래소, 망간, 가격, 방법, 금속, 거래소에서, 망간, 가격, 찾...            1
# 37           [스테인리스, 제작, 방버, 제작방버, 스테인리스, 제작, 방버, 제작방버]            1
# 39                   [성분, 제조법, 제조법, 성분, 및, 제조법, 및, 제조법]            0
# ...                                                 ...          ...
# 1856  [날판, 설계, 단어, 뜻, 설계를, 매들이, 단어가, 무슨뜻인지, 날판, 설계, ...            0
# 1867  [그룹, 타의, 모범, 사례, 작성, 타의, 모범이, 되는, 사례를, 간략하게, 작...            0
# 1868  [그룹, 리더십, 관점, 타의, 모범, 사례, 작성, 리더십, 관점에서, 타의, 모...            0
# 1869  [리더, 업무, 비, 윤리, 인간, 존중, 윤리, 관련, 우수, 사항, 작성, 업무...            0
# 1871  [Sl.No, Documents, Estimation, Corrosion, Rate...            1
#
# [404 rows x 4 columns]

# %%
filtered_df = df2_q[df2_q['Nouns'].apply(lambda nouns: '탱크' in nouns)]
filtered_df.groupby(['UserCode'])['Nouns'].count().reset_index()
# Out:
#    UserCode  Nouns
# 0       203     15

# %%
df = df2_q.groupby('UserCode')['Nouns'].sum().reset_index(name='NounUsed')
df
# Out:
#     UserCode                                           NounUsed
# 0         79  [포스코, 대해, 알, 내용, 알고, 있는, 내용, 포스코, 대해, 알, 내용, 설...
# 1        203  [시세, Mn, 시세를, 찾고, 싶은데, 시세, Mn, 시세를, 찾고, 싶은데, 망...
# 2        279  [철강, 후판, 생산, 공정은, 후판의, 생산, 공정은, 것이, 있습니까, 철강, ...
# 3        297  [대한민국, 풍력, 타워, 풍력, 타워, 대한민국, 풍력, 타워, 풍력, 타워, 대...
# 4        473  [이사회, 인사말, 인사말, 알려줘, 이사회, 인사말, 인사말, 알려줘, 재난, 관...
# 5        941  [price, plate, steel, price, plate, steel, 열교환...
# 6        965  [광양, 소, 탄소강, 후판, 날판, 평균, 실수, 율, 대로, 유지, 게, 실수,...
# 7       1321  [선박, 연료, 유, 종류, 연료유, 종류는, 선박, 연료, 유, 종류, 연료유, ...
# 8       1372  [주물, 제품, 종류, 만드는, 제품의, 종류를, 알려줘, 주물, 제품, 종류, 만...
# 9       1780  [=, y가, x는, =, y가, x는, =, y가, x는, =, 에서, y가, x...
# 10      2227  [difference, s355kl, s355kt, difference, s355k...
# 11      2384         [rust, zinc, coating, rust, zinc, coating]
# 12      2385  [module, Frame, development, contents, module,...
# 13      2457  [포스코, 몇개, 몇개야, 포스코, 고로, 몇개, 고로, 몇개야, 몇개, POSCO...
# 14      2557  [선박, 엔진, 시장, 점유, 율, 대해, 시장, 점유율에, 알려주세요, 선박, 엔...
# 15      2624  [풍력발전, 용, 소재, 판매, 확대, 위햇, 활동, 요, 소재, 판매, 확대를, ...
# 16      2630  [이란, CBAM이란, 무엇인가요, 이란, 무엇, CBAM이란, 무엇인가요, 시계,...
# 17      2642  [뜻, trough가, 뜻이야, 무슨, 뜻, trough가, 무슨, 뜻이야, 태양열...
# 18      2647  [산업, 안전, 보건, 법, 보호대, 고용, 노무, 제공, 사람, 산업, 재해, 보...
# 19      2768  [•How, economies, scale, organization, time, m...
# 20      3264  [회기, 분석, 분석이, 가능한가, 회기, 분석, 분석이, 가능한가, 망간, 내식성...

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

# 이전에 주어진 데이터프레임에서 NounUsed 열을 사용하여 집합 생성
user_sets = {
    row['UserCode']: set(row['NounUsed']) for _, row in df.iterrows()
}

# 벤 다이어그램 그리기
user_labels = {code: f"UserCode {code}" for code in user_sets.keys()}
venn_labels = {label: len(user_sets[code]) for code, label in user_labels.items()}


plt.title("벤 다이어그램")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\codes\gpt_log\src\pgpt_analysis_esm.ipynb Cell 52 line 1
#      <a href='vscode-notebook-cell:/e%3A/codes/gpt_log/src/pgpt_analysis_esm.ipynb#Y102sZmlsZQ%3D%3D?line=9'>10</a> user_labels = {code: f"UserCode {code}" for code in user_sets.keys()}
#      <a href='vscode-notebook-cell:/e%3A/codes/gpt_log/src/pgpt_analysis_esm.ipynb#Y102sZmlsZQ%3D%3D?line=10'>11</a> venn_labels = {label: len(user_sets[code]) for code, label in user_labels.items()}
# ---> <a href='vscode-notebook-cell:/e%3A/codes/gpt_log/src/pgpt_analysis_esm.ipynb#Y102sZmlsZQ%3D%3D?line=11'>12</a> venn2(subsets=(venn_labels['UserCode 79'], venn_labels['UserCode 203'], len(user_sets['UserCode 79'] & user_sets['UserCode 203'])),
#      <a href='vscode-notebook-cell:/e%3A/codes/gpt_log/src/pgpt_analysis_esm.ipynb#Y102sZmlsZQ%3D%3D?line=12'>13</a>       set_labels=('UserCode 79', 'UserCode 203'))
#      <a href='vscode-notebook-cell:/e%3A/codes/gpt_log/src/pgpt_analysis_esm.ipynb#Y102sZmlsZQ%3D%3D?line=13'>14</a> venn2_circles(subsets=(venn_labels['UserCode 79'], venn_labels['UserCode 203'], len(user_sets['UserCode 79'] & user_sets['UserCode 203'])))
#      <a href='vscode-notebook-cell:/e%3A/codes/gpt_log/src/pgpt_analysis_esm.ipynb#Y102sZmlsZQ%3D%3D?line=14'>15</a> venn2_unweighted(subsets=(1, 1, 1), set_labels=('UserCode 79', 'UserCode 203'))
#
# KeyError: 'UserCode 79'

# %%
df_keyword_2
# Out:
#          words  frequency
# 0          LNG         80
# 1           풍력         62
# 2          터미널         62
# 3          태양광         60
# 4           탱크         50
# ..         ...        ...
# 216     Hybrid          2
# 217  Hydrogen에          2
# 218       MSDS          2
# 219       Mill          2
# 220      ZM275          2
#
# [221 rows x 2 columns]

# %%
# for word in dict_temp:
#     for idx in range(len(df.columns)):
#         column_name = df.columns[idx]
#         column_data = df.iloc[:,idx]
#         if  word in column_data['NounUsed']:
#             dict_temp[word].append(column_data['UserCode'])

dict_temp = {key:[] for key in df_keyword_2['words'].tolist()}

for idx, row in df.iterrows():
    user_code = row['UserCode']
    nouns_used = row['NounUsed']

    for word, word_list in dict_temp.items():
        if any(term in nouns_used for term in [word]):
            word_list.append(user_code)

# # dict_temp을 활용하여 새로운 데이터프레임 생성
# result_data = {key: value for key, value in dict_temp.items()}
# result_df = pd.DataFrame(result_data)

# # 결과 출력
# print(result_df)
dict_temp
# Out:
# {'LNG': [203],
#  '풍력': [203, 297, 2630],
#  '터미널': [203],
#  '태양광': [79, 2385],
#  '탱크': [203],
#  '용접': [203],
#  '후판': [203, 279, 965, 1321, 1372],
#  '강재': [203, 279, 297, 965],
#  '철강': [203, 279, 941, 2385],
#  'steel': [79, 203, 941, 1372],
#  '내식성': [203, 3264],
#  '강': [203, 297, 941],
#  '타워': [203, 297, 2630],
#  '기계': [203, 1372],
#  '규격': [279, 965],
#  '열처리': [203, 941, 965],
#  'tank': [203],
#  '제철소': [203],
#  '터빈': [297],
#  'Solar': [2385, 2642],
#  '망간': [203, 297, 3264],
#  '해상풍력': [203, 297],
#  '저장탱크': [203],
#  '고Mn강': [203],
#  '저장탱크별': [203],
#  '선박': [79, 1321, 2557],
#  'EN-S355J0AR': [965],
#  'DNV': [203],
#  'Plate': [203],
#  '패널': [2385],
#  '탄소': [1372, 2385],
#  'LNG터미널별': [203],
#  '탄소강': [965],
#  'V42JPB3의': [965],
#  'hydrogen': [2385],
#  '해상풍력타워': [203],
#  '메탄올': [279, 1321],
#  '주물': [965, 1372],
#  'A578': [203],
#  'LNG탱크': [203],
#  '태양열': [2642],
#  'SSAB의': [1372],
#  '풍력타워': [2630],
#  'BIS20TP': [965],
#  'Mn': [203],
#  '성능향상강재': [297],
#  'LNG터미널': [203],
#  'Steel': [203],
#  '니켈': [203],
#  '풍력발전': [297, 2624],
#  'SUS304': [203],
#  'EN-S275J0AR로': [965],
#  'EN-S275J0AR의': [965],
#  '고Mn강의': [203],
#  'LT-FH51': [203],
#  'CTOD': [203],
#  'LT-F51': [203],
#  'SAGD': [203],
#  'X80': [203],
#  '발전소': [297],
#  '발전소는': [297],
#  '가스터빈': [297],
#  '고망간': [203, 3264],
#  'STS304': [203, 3264],
#  '디스크': [203],
#  '연마': [203],
#  '디스크의': [203],
#  '연마하거나': [203],
#  '프레임': [2385],
#  '고로': [2457],
#  '스테인리스': [203],
#  '저장탱크에': [203],
#  '메탄올추진선': [279],
#  '스틸': [203],
#  '플라워': [203],
#  '스틸플라워': [203],
#  '풍력용': [297],
#  '탱크별': [203],
#  '멤브레인': [203],
#  'Ni과': [203],
#  '강재의': [297],
#  '하부구조물의': [297],
#  '부유식해상풍력과': [297],
#  '고정식해상풍력의': [297],
#  '카본파이버': [203],
#  'ETF가': [203],
#  'FIO에': [79],
#  'FIO': [79],
#  'PosMac': [203],
#  'PosMac과': [203],
#  'PosMac3.0과': [203],
#  'CBAM': [1321],
#  '주물제품을': [1372],
#  '리트로핏': [1321],
#  '수에즈': [1321],
#  '막스': [1321],
#  '수에즈막스': [1321],
#  '제철소에서': [203],
#  '제철소에': [203],
#  '원자로': [203],
#  '용강': [203],
#  'LNG저장탱크용': [203],
#  '저온용강': [203],
#  '고Mn강이란': [203],
#  '열처리를': [965],
#  '추출': [965],
#  '온도': [965],
#  '공정': [965],
#  '압연추출온도': [965],
#  '통과공정': [965],
#  '보일러': [297],
#  '가스터빈은': [297],
#  '열교환기': [941],
#  '반응기는': [941],
#  '스팀드럼은': [941],
#  '스팀드럼': [941],
#  '열처리설비를': [941],
#  's355kl': [2227],
#  's355kt': [2227],
#  '엔진': [2557],
#  'CBAM이란': [2630],
#  'trough가': [2642],
#  'heliostat가': [2642],
#  'stirling이': [2642],
#  'fresnel이': [2642],
#  'fabricator': [2385],
#  'manufacture': [2385],
#  '초연결': [203],
#  'rust': [2384],
#  'zinc': [2384],
#  '코일': [79],
#  '지석검사에': [79],
#  'coil': [79],
#  'DQT': [2227],
#  'QT': [2227],
#  '태양광패널': [2385],
#  'MODULE': [79],
#  '구조물용': [79],
#  '지붕형': [2385],
#  '태양광에': [2385],
#  '소재는': [2385],
#  '조재용': [2385],
#  '구조재용': [2385],
#  'PosMAC은': [2385],
#  'solar': [2642],
#  'lng터미널': [203],
#  'SSAB': [1372],
#  'STS': [203],
#  '내식성을': [203],
#  'P690': [203],
#  '표면은': [203],
#  '표면의': [203],
#  '거칠기와': [203],
#  '피로에': [203],
#  '피로균열이': [203],
#  '피로성능': [203],
#  '피로균열': [203],
#  '피로균열을': [203],
#  '용접부의': [203],
#  '내구성에': [203],
#  '용접속도와': [203],
#  '입열량을': [203],
#  '내피로강': [203],
#  '용접재료': [203],
#  'LR은': [279],
#  'LTFH36': [279],
#  'LCO2': [279],
#  '운반선': [279],
#  '도장의': [203],
#  '용삭': [203],
#  '도장이': [203],
#  '물질': [965],
#  'Zinc': [2642],
#  '해상': [203, 297],
#  '피로': [203],
#  '표면': [203],
#  '가공': [203],
#  'PJT': [203, 2385],
#  '수소': [203, 2385],
#  '소재': [79, 2385, 2624],
#  '강종': [203],
#  '피로성능을': [203],
#  'Ni': [203],
#  'tanks': [203],
#  '철': [203],
#  '용접부': [203],
#  '조선': [203, 1321],
#  'surface': [79],
#  'blast': [2457],
#  'furnaces': [2457],
#  '표층': [203],
#  '금속': [203],
#  '공정은': [279],
#  '후판의': [279, 1321],
#  '터빈의': [297],
#  '강관': [203],
#  '강재소요량에': [203],
#  'HQs': [2642],
#  '도장': [203],
#  'plate': [941],
#  '연료유': [1321],
#  '연료유는': [1321],
#  '메탄올은': [1321],
#  '부정합': [203],
#  'UT검사': [203],
#  'V42JPB3은': [965],
#  'Strap이': [203],
#  '압하비': [965],
#  'COD': [203],
#  'UT': [203],
#  'Pipe': [941],
#  '고로가': [2457],
#  '황': [2385],
#  '강재개발': [203],
#  'lng': [203],
#  'BIS20P': [965],
#  'Hybrid': [2385],
#  'Hydrogen에': [2385],
#  'MSDS': [2642],
#  'Mill': [2642],
#  'ZM275': [2642]}

# %%
sorted_dict_temp = dict(sorted(dict_temp.items(), key=lambda x: len(x[1]), reverse=True))
sorted_dict_temp
# Out:
# {'후판': [203, 279, 965, 1321, 1372],
#  '강재': [203, 279, 297, 965],
#  '철강': [203, 279, 941, 2385],
#  'steel': [79, 203, 941, 1372],
#  '풍력': [203, 297, 2630],
#  '강': [203, 297, 941],
#  '타워': [203, 297, 2630],
#  '열처리': [203, 941, 965],
#  '망간': [203, 297, 3264],
#  '선박': [79, 1321, 2557],
#  '소재': [79, 2385, 2624],
#  '태양광': [79, 2385],
#  '내식성': [203, 3264],
#  '기계': [203, 1372],
#  '규격': [279, 965],
#  'Solar': [2385, 2642],
#  '해상풍력': [203, 297],
#  '탄소': [1372, 2385],
#  '메탄올': [279, 1321],
#  '주물': [965, 1372],
#  '풍력발전': [297, 2624],
#  '고망간': [203, 3264],
#  'STS304': [203, 3264],
#  '해상': [203, 297],
#  'PJT': [203, 2385],
#  '수소': [203, 2385],
#  '조선': [203, 1321],
#  '후판의': [279, 1321],
#  'LNG': [203],
#  '터미널': [203],
#  '탱크': [203],
#  '용접': [203],
#  'tank': [203],
#  '제철소': [203],
#  '터빈': [297],
#  '저장탱크': [203],
#  '고Mn강': [203],
#  '저장탱크별': [203],
#  'EN-S355J0AR': [965],
#  'DNV': [203],
#  'Plate': [203],
#  '패널': [2385],
#  'LNG터미널별': [203],
#  '탄소강': [965],
#  'V42JPB3의': [965],
#  'hydrogen': [2385],
#  '해상풍력타워': [203],
#  'A578': [203],
#  'LNG탱크': [203],
#  '태양열': [2642],
#  'SSAB의': [1372],
#  '풍력타워': [2630],
#  'BIS20TP': [965],
#  'Mn': [203],
#  '성능향상강재': [297],
#  'LNG터미널': [203],
#  'Steel': [203],
#  '니켈': [203],
#  'SUS304': [203],
#  'EN-S275J0AR로': [965],
#  'EN-S275J0AR의': [965],
#  '고Mn강의': [203],
#  'LT-FH51': [203],
#  'CTOD': [203],
#  'LT-F51': [203],
#  'SAGD': [203],
#  'X80': [203],
#  '발전소': [297],
#  '발전소는': [297],
#  '가스터빈': [297],
#  '디스크': [203],
#  '연마': [203],
#  '디스크의': [203],
#  '연마하거나': [203],
#  '프레임': [2385],
#  '고로': [2457],
#  '스테인리스': [203],
#  '저장탱크에': [203],
#  '메탄올추진선': [279],
#  '스틸': [203],
#  '플라워': [203],
#  '스틸플라워': [203],
#  '풍력용': [297],
#  '탱크별': [203],
#  '멤브레인': [203],
#  'Ni과': [203],
#  '강재의': [297],
#  '하부구조물의': [297],
#  '부유식해상풍력과': [297],
#  '고정식해상풍력의': [297],
#  '카본파이버': [203],
#  'ETF가': [203],
#  'FIO에': [79],
#  'FIO': [79],
#  'PosMac': [203],
#  'PosMac과': [203],
#  'PosMac3.0과': [203],
#  'CBAM': [1321],
#  '주물제품을': [1372],
#  '리트로핏': [1321],
#  '수에즈': [1321],
#  '막스': [1321],
#  '수에즈막스': [1321],
#  '제철소에서': [203],
#  '제철소에': [203],
#  '원자로': [203],
#  '용강': [203],
#  'LNG저장탱크용': [203],
#  '저온용강': [203],
#  '고Mn강이란': [203],
#  '열처리를': [965],
#  '추출': [965],
#  '온도': [965],
#  '공정': [965],
#  '압연추출온도': [965],
#  '통과공정': [965],
#  '보일러': [297],
#  '가스터빈은': [297],
#  '열교환기': [941],
#  '반응기는': [941],
#  '스팀드럼은': [941],
#  '스팀드럼': [941],
#  '열처리설비를': [941],
#  's355kl': [2227],
#  's355kt': [2227],
#  '엔진': [2557],
#  'CBAM이란': [2630],
#  'trough가': [2642],
#  'heliostat가': [2642],
#  'stirling이': [2642],
#  'fresnel이': [2642],
#  'fabricator': [2385],
#  'manufacture': [2385],
#  '초연결': [203],
#  'rust': [2384],
#  'zinc': [2384],
#  '코일': [79],
#  '지석검사에': [79],
#  'coil': [79],
#  'DQT': [2227],
#  'QT': [2227],
#  '태양광패널': [2385],
#  'MODULE': [79],
#  '구조물용': [79],
#  '지붕형': [2385],
#  '태양광에': [2385],
#  '소재는': [2385],
#  '조재용': [2385],
#  '구조재용': [2385],
#  'PosMAC은': [2385],
#  'solar': [2642],
#  'lng터미널': [203],
#  'SSAB': [1372],
#  'STS': [203],
#  '내식성을': [203],
#  'P690': [203],
#  '표면은': [203],
#  '표면의': [203],
#  '거칠기와': [203],
#  '피로에': [203],
#  '피로균열이': [203],
#  '피로성능': [203],
#  '피로균열': [203],
#  '피로균열을': [203],
#  '용접부의': [203],
#  '내구성에': [203],
#  '용접속도와': [203],
#  '입열량을': [203],
#  '내피로강': [203],
#  '용접재료': [203],
#  'LR은': [279],
#  'LTFH36': [279],
#  'LCO2': [279],
#  '운반선': [279],
#  '도장의': [203],
#  '용삭': [203],
#  '도장이': [203],
#  '물질': [965],
#  'Zinc': [2642],
#  '피로': [203],
#  '표면': [203],
#  '가공': [203],
#  '강종': [203],
#  '피로성능을': [203],
#  'Ni': [203],
#  'tanks': [203],
#  '철': [203],
#  '용접부': [203],
#  'surface': [79],
#  'blast': [2457],
#  'furnaces': [2457],
#  '표층': [203],
#  '금속': [203],
#  '공정은': [279],
#  '터빈의': [297],
#  '강관': [203],
#  '강재소요량에': [203],
#  'HQs': [2642],
#  '도장': [203],
#  'plate': [941],
#  '연료유': [1321],
#  '연료유는': [1321],
#  '메탄올은': [1321],
#  '부정합': [203],
#  'UT검사': [203],
#  'V42JPB3은': [965],
#  'Strap이': [203],
#  '압하비': [965],
#  'COD': [203],
#  'UT': [203],
#  'Pipe': [941],
#  '고로가': [2457],
#  '황': [2385],
#  '강재개발': [203],
#  'lng': [203],
#  'BIS20P': [965],
#  'Hybrid': [2385],
#  'Hydrogen에': [2385],
#  'MSDS': [2642],
#  'Mill': [2642],
#  'ZM275': [2642]}
